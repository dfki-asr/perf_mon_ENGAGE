# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
  except RuntimeError as e:
    print(e)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Input, Flatten,\
Conv2DTranspose, BatchNormalization, LeakyReLU, Reshape, MaxPooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.datasets import cifar10
import tensorflow.keras.backend as K
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

# %%
# input image dimensions
img_rows, img_cols = 32, 32
# Load CIFAR-10 dataset-
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
if tf.keras.backend.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 3)
    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

# %%
# Specify hyper-parameters-
batch_size = 64
num_classes = 10
num_epochs = 500

# %%
# Convert datasets to floating point types-
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the training and testing datasets-
X_train /= 255.0
X_test /= 255.0

print("\nDimensions of training and testing sets are:")
print(f"X_train.shape: {X_train.shape} & X_test.shape: {X_test.shape}")


# Create TF datasets-
train_dataset = tf.data.Dataset.from_tensor_slices(X_train).shuffle(50000).batch(batch_size = batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices(X_test).shuffle(10000).batch(batch_size = batch_size)
# Out:
# Dimensions of training and testing sets are:
# X_train.shape: (50000, 32, 32, 3) & X_test.shape: (10000, 32, 32, 3)

# %%
class ConvBlock(Model):
    def __init__(
        self, num_filters,
        kernel_size, stride_length,
        pooling_size, pooling_stride,
        padding_type = 'same'
    ):
        super(ConvBlock, self).__init__()
        
        self.conv1 = Conv2D(
            filters = num_filters, kernel_size = kernel_size,
            strides = stride_length, padding = padding_type,
            activation = None, use_bias = False,
        )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv2 = Conv2D(
            filters = num_filters, kernel_size = kernel_size,
            strides = stride_length, padding = padding_type,
            activation = None, use_bias = False
        )
        self.bn2 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.pool = MaxPooling2D(
            pool_size = pooling_size,
            strides = pooling_stride
        )
        
    
    def call(self, x):
        x = tf.keras.activations.relu(self.bn(self.conv1(x)))
        x = tf.keras.activations.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        
        return x

# %%
class Conv6_Encoder(Model):
    def __init__(self, latent_dim = 10):
        super(Conv6_Encoder, self).__init__()

        self.latent_dim = latent_dim
        
        self.conv_block1 = ConvBlock(
            num_filters = 64, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'valid'
            )

        self.conv_block2 = ConvBlock(
            num_filters = 128, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'valid'
            )
        
        self.conv_block3 = ConvBlock(
            num_filters = 256, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'same'
            )

        self.flatten = Flatten()
        
        self.output_layer = Dense(
            units = self.latent_dim, activation = None
            )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
    
    def call(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.flatten(x)
        x = tf.keras.activations.relu(self.bn(self.output_layer(x)))
        return x
    
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (32, 32, 3))
        return Model(inputs = [x], outputs = self.call(x))
    
    def shape_computation(self, x):
        print(f"Input shape: {x.shape}")
        x = self.conv_block1(x)
        print(f"conv_block1.shape: {x.shape}")
        x = self.conv_block2(x)
        print(f"conv_block2.shape: {x.shape}")
        x = self.conv_block3(x)
        print(f"conv_block3.shape: {x.shape}")
        x = self.flatten(x)
        print(f"flattened shape: {x.shape}")
        x = tf.keras.activations.relu(self.bn(self.output_layer(x)))
        print(f"Encoder output shape: {x.shape}")
        '''
        Input shape: (64, 32, 32, 3)
        conv_block1.shape: (64, 14, 14, 64)
        conv_block2.shape: (64, 5, 5, 128)
        conv_block3.shape: (64, 2, 2, 256)
        flattened shape: (64, 1024)
        Encoder output shape: (64, 100)
        '''
        
        return None

# %%
class Conv6_Decoder(Model):
    def __init__(self, latent_dim = 10):
        super(Conv6_Decoder, self).__init__()

        self.latent_dim = latent_dim
        
        # self.inp_layer = InputLayer(input_shape = self.latent_dim)
        
        self.dense0 = Dense(
            units = self.latent_dim, activation = None
            )
        self.bn0 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.dense = Dense(
            units = 1024, activation = None
        )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.dense2 = Dense(
            units = 4 * 4 * 256, activation = None
        )
        self.bn2 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.reshape = Reshape((4, 4, 256))
        
        self.conv_transpose_layer1 = Conv2DTranspose(
            filters = 256, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn3 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
       
        self.conv_transpose_layer2 = Conv2DTranspose(
            filters = 256, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn4 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv_transpose_layer3 =  Conv2DTranspose(
            filters = 128, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn5 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv_transpose_layer4 = Conv2DTranspose(
            filters = 128, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn6 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )

        self.conv_transpose_layer5 = Conv2DTranspose(
            filters = 64, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn7 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
       
        self.conv_transpose_layer6 = Conv2DTranspose(
            filters = 64, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn8 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.final_conv_layer = Conv2DTranspose(
            filters = 3, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
    
    def call(self, X):
        # X = self.inp_layer(X)
        X = tf.keras.activations.relu(self.bn0(self.dense0(X)))
        X = tf.keras.activations.relu(self.bn(self.dense(X)))
        X = tf.keras.activations.relu(self.bn2(self.dense2(X)))
        X = self.reshape(X)
        X = tf.keras.activations.relu(self.bn3(self.conv_transpose_layer1(X)))
        X = tf.keras.activations.relu(self.bn4(self.conv_transpose_layer2(X)))
        X = tf.keras.activations.relu(self.bn5(self.conv_transpose_layer3(X)))
        X = tf.keras.activations.relu(self.bn6(self.conv_transpose_layer4(X)))
        X = tf.keras.activations.relu(self.bn7(self.conv_transpose_layer5(X)))
        X = tf.keras.activations.relu(self.bn8(self.conv_transpose_layer6(X)))
        # X = tf.keras.activations.sigmoid(self.final_conv_layer(X))
        X = self.final_conv_layer(X)

        return X
        
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (100))
        return Model(inputs = [x], outputs = self.call(x))
    
    def shape_computation(self, x):
        print(f"Input shape: {x.shape}")
        x = tf.nn.relu(self.bn0(self.dense0(x)))
        print(f"first dense layer shape: {x.shape}")
        x = tf.nn.relu(self.bn(self.dense(x)))
        print(f"second dense layer shape: {x.shape}")
        x = tf.nn.relu(self.bn2(self.dense2(x)))
        print(f"third dense layer shape: {x.shape}")
        x = self.reshape(x)
        print(f"reshape: {x.shape}")
        x = tf.nn.relu(self.bn3(self.conv_transpose_layer1(x)))
        print(f"conv transpose layer1 shape: {x.shape}")
        x = tf.nn.relu(self.bn4(self.conv_transpose_layer2(x)))
        print(f"conv transpose layer2 shape: {x.shape}")
        x = tf.nn.relu(self.bn5(self.conv_transpose_layer3(x)))
        print(f"conv transpose layer3 shape: {x.shape}")
        x = tf.nn.relu(self.bn6(self.conv_transpose_layer4(x)))
        print(f"conv transpose layer4 shape: {x.shape}")
        x = tf.nn.relu(self.bn7(self.conv_transpose_layer5(x)))
        print(f"conv transpose layer5 shape: {x.shape}")
        x = tf.nn.relu(self.bn8(self.conv_transpose_layer6(x)))
        print(f"conv transpose layer6 shape: {x.shape}")
        x = self.final_conv_layer(x)
        print(f"Decoder output shape: {x.shape}")
        
        '''
        Input shape: (64, 100)
        first dense layer shape: (64, 100)
        second dense layer shape: (64, 1024)
        third dense layer shape: (64, 4096)
        reshape: (64, 4, 4, 256)
        conv transpose layer1 shape: (64, 8, 8, 256)
        conv transpose layer2 shape: (64, 8, 8, 256)
        conv transpose layer3 shape: (64, 16, 16, 128)
        conv transpose layer4 shape: (64, 16, 16, 128)
        conv transpose layer5 shape: (64, 32, 32, 64)
        conv transpose layer6 shape: (64, 32, 32, 64)
        Decoder output shape: (64, 32, 32, 3)
        '''
        
        return None

# %%
class Sampling(tf.keras.layers.Layer):
    """
    Create a sampling layer.
    Uses (mu, log_var) to sample latent vector 'z'.
    """
    def call(self, mu, log_var):
    # def call(self, inputs):
        # z_mean, z_log_var = inputs

        # Get batch size-
        batch = tf.shape(mu)[0]

        # Get latent space dimensionality-
        dim = tf.shape(mu)[1]

        # Add stochasticity by sampling from a multivariate standard 
        # Gaussian distribution-
        epsilon = tf.keras.backend.random_normal(
            shape = (batch, dim), mean = 0.0,
            stddev = 1.0
        )

        return mu + (tf.exp(0.5 * log_var) * epsilon)

# %%
class VAE(Model):
    def __init__(self, latent_space = 100):
        super(VAE, self).__init__()
        
        self.latent_space = latent_space
        
        self.encoder = Conv6_Encoder(latent_dim = self.latent_space)
        self.decoder = Conv6_Decoder(latent_dim = self.latent_space)
        
        # Define fully-connected layers for computing mean & log variance-
        self.mu = Dense(units = self.latent_space, activation = None)
        self.log_var = Dense(units = self.latent_space, activation = None)


    def reparameterize(self, mu, logvar):
        # Sample from a multivariate Gaussian distribution.
        # Adds stochasticity or variation-
        eps = tf.random.normal(
            shape = mu.shape, mean = 0.0,
            stddev = 1.0
        )
        return (eps * tf.exp(logvar * 0.5) + mu)
        
    
    def call(self, x):
        x = self.encoder(x)
        # print(f"x.shape: {x.shape}")
        # x.shape: (batch_size, 100)
        
        mu = self.mu(x)
        log_var = self.log_var(x)
        # z = self.reparameterize(mu, log_var)
        # z = Sampling()([mu, log_var])
        z = Sampling()(mu, log_var)
        '''
        print(f"mu.shape: {mu.shape}, log_var.shape: {log_var.shape}"
              f" & z.shape: {z.shape}")
        # mu.shape: (batch_size, 100), log_var.shape: (batch_size, 100) & z.shape: (batch_size, 100)
        '''
        
        x = tf.keras.activations.sigmoid(self.decoder(z))
        return x, mu, log_var, z
    
    
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (32, 32, 3))
        return Model(inputs = [x], outputs = self.call(x))

# %%
# Initialize VAE model-
model = VAE(latent_space = 100)

# %%
# Get model summary-
model.model().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv6__encoder (Conv6_Encoder)  (None, 100)         1250996     ['input_1[0][0]']
#
#  dense_4 (Dense)                (None, 100)          10100       ['conv6__encoder[0][0]']
#
#  dense_5 (Dense)                (None, 100)          10100       ['conv6__encoder[0][0]']
#
#  sampling (Sampling)            (None, 100)          0           ['dense_4[0][0]',
#                                                                   'dense_5[0][0]']
#
#  conv6__decoder (Conv6_Decoder)  (None, 32, 32, 3)   6071623     ['sampling[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, 32, 32, 3)    0           ['conv6__decoder[0][0]']
#
# ==================================================================================================
# Total params: 7,342,819
# Trainable params: 7,328,595
# Non-trainable params: 14,224
# __________________________________________________________________________________________________

# %%
# Define an optimizer-
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4)

# %%
def compute_loss(data, reconstruction, mu, log_var, alpha = 1):
    
    # Reconstruction loss-
    # recon_loss = tf.keras.losses.mean_squared_error(K.flatten(data), K.flatten(reconstruction))

    recon_loss = tf.reduce_mean(
        tf.reduce_sum(
            tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
#             tf.keras.losses.mean_squared_error(data, reconstruction),
#             axis = (1, 2)
            )
        )
    
    # KL-divergence loss-    
    kl_loss = -0.5 * (1 + log_var - tf.square(mu) - tf.exp(log_var))
    kl_loss = tf.reduce_mean(
        tf.reduce_sum(
            kl_loss,
            axis = 1
        )
    )

    total_loss = (recon_loss * alpha) + kl_loss
    
    return total_loss, recon_loss, kl_loss

# %%
@tf.function
def train_one_step(model, optimizer, data, alpha):
    # Function to perform one step/iteration of training

    with tf.GradientTape() as tape:
        # Make predictions using defined model-
        data_recon, mu, log_var, z = model(data)

        # Compute loss-
        total_loss, recon_loss, kl_loss = compute_loss(
            data = data, reconstruction = data_recon,
            mu = mu, log_var = log_var,
            alpha = alpha
        )
    
    # Compute gradients wrt defined loss and weights and biases-
    grads = tape.gradient(total_loss, model.trainable_variables)
    
    # type(grads)
    # list
    
    # Apply computed gradients to model's weights and biases-
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return total_loss, recon_loss, kl_loss


@tf.function
def test_step(model, optimizer, data, alpha):
    '''
    Function to test model performance
    on testing dataset
    '''
    # Make predictions using defined model-
    data_recon, mu, log_var, z = model(data)
    
    # Compute loss-
    total_loss, recon_loss, kl_loss = compute_loss(
        data = data, reconstruction = data_recon,
        mu = mu, log_var = log_var,
        alpha = alpha
    )
    
    return total_loss, recon_loss, kl_loss

# %%
# Specify hyper-parameter for reconstruction loss vs. kl-divergence-
alpha = 10

# Python3 dict to contain training metrics-
training_metrics = {}
val_metrics = {}

# %%
for epoch in range(1, num_epochs + 1):
    """
    # Manual early stopping implementation-
    if loc_patience >= patience:
        print("\n'EarlyStopping' called!\n")
        break
    """

    # Epoch train & validation losses-
    train_loss = 0.0
    train_r_loss = 0.0
    train_kl_l = 0.0
    val_loss = 0.0
    val_r_loss = 0.0
    val_kl_l = 0.0
    
    for data in train_dataset:
        train_total_loss, train_recon_loss, train_kl_loss = train_one_step(
            model = model, optimizer = optimizer,
            data = data, alpha = alpha
        )
        
        train_loss += train_total_loss.numpy()
        train_r_loss += train_recon_loss.numpy()
        train_kl_l += train_kl_loss.numpy()
    
    for test_data in test_dataset:
        test_total_loss, test_recon_loss, test_kl_loss = test_step(
            model = model, optimizer = optimizer,
            data = test_data, alpha = alpha)
        
        val_loss += test_total_loss.numpy()
        val_r_loss += test_recon_loss.numpy()
        val_kl_l += test_kl_loss.numpy()
    
    # vae_train_loss.append(train_loss)
    # vae_val_loss.append(val_loss)

    training_metrics[epoch] = {
        'total_loss': train_loss, 'recon_loss': train_r_loss,
        'kl_loss': train_kl_l
        }
    
    val_metrics[epoch] = {
        'total_loss': val_loss, 'recon_loss': val_r_loss,
        'kl_loss': val_kl_l
    }

    print(f"epoch = {epoch}; total train loss = {train_loss:.4f},"
    f" train recon loss = {train_r_loss:.4f}, train kl loss = {train_kl_l:.4f};"
    f" total val loss = {val_loss:.4f}, val recon loss = {val_r_loss:.4f} &"
    f" val kl loss = {val_kl_l:.4f}"
    )
# Out:
# epoch = 1; total train loss = 5192625.6147, train recon loss = 517126.3174, train kl loss = 21362.4460; total val loss = 1003830.3560, val recon loss = 99638.6539 & val kl loss = 7443.8155
# epoch = 2; total train loss = 4953826.4463, train recon loss = 491091.1230, train kl loss = 42915.2145; total val loss = 989869.5093, val recon loss = 98093.2885 & val kl loss = 8936.6264
# epoch = 3; total train loss = 4907953.7476, train recon loss = 486154.2944, train kl loss = 46410.8069; total val loss = 983568.6675, val recon loss = 97404.2853 & val kl loss = 9525.8146
# epoch = 4; total train loss = 4863474.7354, train recon loss = 481116.6631, train kl loss = 52308.1053; total val loss = 977519.8672, val recon loss = 96640.1116 & val kl loss = 11118.7559
# epoch = 5; total train loss = 4828112.4971, train recon loss = 477397.5571, train kl loss = 54136.9267; total val loss = 970976.2490, val recon loss = 96022.4727 & val kl loss = 10751.5237
# epoch = 6; total train loss = 4816033.9893, train recon loss = 476257.2162, train kl loss = 53461.8300; total val loss = 969296.5596, val recon loss = 95844.5380 & val kl loss = 10851.1746
# epoch = 7; total train loss = 4803287.5454, train recon loss = 474912.1668, train kl loss = 54165.8673; total val loss = 967188.2710, val recon loss = 95603.9199 & val kl loss = 11149.0723
# epoch = 8; total train loss = 4790114.3501, train recon loss = 473453.7073, train kl loss = 55577.2734; total val loss = 963452.0391, val recon loss = 95236.3005 & val kl loss = 11089.0317
# epoch = 9; total train loss = 4777521.5972, train recon loss = 472154.9893, train kl loss = 55971.7036; total val loss = 959577.8706, val recon loss = 94818.4932 & val kl loss = 11392.9355
# epoch = 10; total train loss = 4768067.4141, train recon loss = 471187.3469, train kl loss = 56193.9426; total val loss = 958402.9048, val recon loss = 94716.3344 & val kl loss = 11239.5624
# epoch = 11; total train loss = 4759178.1357, train recon loss = 470313.7806, train kl loss = 56040.3303; total val loss = 956306.5073, val recon loss = 94513.9661 & val kl loss = 11166.8426
# epoch = 12; total train loss = 4751515.4629, train recon loss = 469599.9543, train kl loss = 55515.9119; total val loss = 955204.6348, val recon loss = 94393.1295 & val kl loss = 11273.3429
# epoch = 13; total train loss = 4745476.5840, train recon loss = 469029.9452, train kl loss = 55177.1188; total val loss = 954275.8384, val recon loss = 94318.3312 & val kl loss = 11092.5206
# epoch = 14; total train loss = 4738150.7896, train recon loss = 468345.2668, train kl loss = 54698.1168; total val loss = 953572.8540, val recon loss = 94272.9101 & val kl loss = 10843.7511
# epoch = 15; total train loss = 4733685.8667, train recon loss = 467977.4649, train kl loss = 53911.2186; total val loss = 951284.0674, val recon loss = 94042.0306 & val kl loss = 10863.7627
# epoch = 16; total train loss = 4727755.7012, train recon loss = 467412.1272, train kl loss = 53634.4163; total val loss = 951252.4644, val recon loss = 94052.2701 & val kl loss = 10729.7573
# epoch = 17; total train loss = 4722241.7485, train recon loss = 466865.5028, train kl loss = 53586.7181; total val loss = 949986.6812, val recon loss = 93906.8578 & val kl loss = 10918.1070
# epoch = 18; total train loss = 4716654.3105, train recon loss = 466298.7903, train kl loss = 53666.4080; total val loss = 948627.8052, val recon loss = 93787.8076 & val kl loss = 10749.7338
# epoch = 19; total train loss = 4711275.6807, train recon loss = 465760.4598, train kl loss = 53671.0860; total val loss = 948897.1802, val recon loss = 93826.7870 & val kl loss = 10629.3139
# epoch = 20; total train loss = 4707131.1045, train recon loss = 465357.7493, train kl loss = 53553.6169; total val loss = 946410.5679, val recon loss = 93562.3289 & val kl loss = 10787.2799
# epoch = 21; total train loss = 4702483.4531, train recon loss = 464913.5728, train kl loss = 53347.7287; total val loss = 946374.8574, val recon loss = 93560.5784 & val kl loss = 10769.0723
# epoch = 22; total train loss = 4699301.3989, train recon loss = 464607.7584, train kl loss = 53223.8204; total val loss = 945635.1396, val recon loss = 93503.5414 & val kl loss = 10599.7294
# epoch = 23; total train loss = 4695338.6157, train recon loss = 464209.2352, train kl loss = 53246.2567; total val loss = 944724.6572, val recon loss = 93407.5516 & val kl loss = 10649.1426
# epoch = 24; total train loss = 4692396.3730, train recon loss = 463906.7326, train kl loss = 53329.0476; total val loss = 944627.8936, val recon loss = 93387.2894 & val kl loss = 10754.9986
# epoch = 25; total train loss = 4689120.9062, train recon loss = 463568.3939, train kl loss = 53436.9584; total val loss = 943267.9077, val recon loss = 93247.9246 & val kl loss = 10788.6612
# epoch = 26; total train loss = 4685900.5308, train recon loss = 463238.0809, train kl loss = 53519.7224; total val loss = 943140.3706, val recon loss = 93231.3301 & val kl loss = 10827.0719
# epoch = 27; total train loss = 4682903.4795, train recon loss = 462943.4880, train kl loss = 53468.6056; total val loss = 944499.9556, val recon loss = 93402.3557 & val kl loss = 10476.3966
# epoch = 28; total train loss = 4680394.8452, train recon loss = 462699.1815, train kl loss = 53403.0262; total val loss = 942372.5664, val recon loss = 93174.3207 & val kl loss = 10629.3628
# epoch = 29; total train loss = 4677773.7471, train recon loss = 462439.5464, train kl loss = 53378.2828; total val loss = 942026.4219, val recon loss = 93144.3351 & val kl loss = 10583.0737
# epoch = 30; total train loss = 4676074.1851, train recon loss = 462266.3259, train kl loss = 53410.9256; total val loss = 941928.0010, val recon loss = 93102.1228 & val kl loss = 10906.7696
# epoch = 31; total train loss = 4673664.7612, train recon loss = 462032.2193, train kl loss = 53342.5634; total val loss = 941517.6250, val recon loss = 93075.9189 & val kl loss = 10758.4335
# epoch = 32; total train loss = 4671147.0122, train recon loss = 461787.1107, train kl loss = 53275.8935; total val loss = 941774.7476, val recon loss = 93113.9456 & val kl loss = 10635.2939
# epoch = 33; total train loss = 4669835.8335, train recon loss = 461666.5353, train kl loss = 53170.4899; total val loss = 941256.0591, val recon loss = 93067.2007 & val kl loss = 10584.0589
# epoch = 34; total train loss = 4667601.6821, train recon loss = 461451.3801, train kl loss = 53087.8824; total val loss = 940351.7266, val recon loss = 92971.3709 & val kl loss = 10638.0194
# epoch = 35; total train loss = 4665834.9995, train recon loss = 461290.7957, train kl loss = 52927.0317; total val loss = 940719.9165, val recon loss = 93040.7411 & val kl loss = 10312.5084
# epoch = 36; total train loss = 4664602.6719, train recon loss = 461175.7291, train kl loss = 52845.3880; total val loss = 940166.8564, val recon loss = 92947.5682 & val kl loss = 10691.1738
# epoch = 37; total train loss = 4662855.3457, train recon loss = 461007.7150, train kl loss = 52778.1899; total val loss = 940651.1094, val recon loss = 93009.1469 & val kl loss = 10559.6410
# epoch = 38; total train loss = 4661524.7778, train recon loss = 460882.3128, train kl loss = 52701.6477; total val loss = 940147.1621, val recon loss = 92957.7592 & val kl loss = 10569.5700
# epoch = 39; total train loss = 4659888.7798, train recon loss = 460726.2122, train kl loss = 52626.6602; total val loss = 939897.9639, val recon loss = 92940.7245 & val kl loss = 10490.7253
# epoch = 40; total train loss = 4658351.7832, train recon loss = 460581.8216, train kl loss = 52533.5539; total val loss = 940454.8838, val recon loss = 92977.6176 & val kl loss = 10678.7094
# epoch = 41; total train loss = 4656681.7290, train recon loss = 460413.5422, train kl loss = 52546.3149; total val loss = 940515.5459, val recon loss = 92972.6880 & val kl loss = 10788.6653
# epoch = 42; total train loss = 4655146.9023, train recon loss = 460255.6802, train kl loss = 52590.0990; total val loss = 939985.6953, val recon loss = 92933.0087 & val kl loss = 10655.6074
# epoch = 43; total train loss = 4653844.5273, train recon loss = 460119.4536, train kl loss = 52649.9925; total val loss = 941294.0088, val recon loss = 93050.4100 & val kl loss = 10789.9062
# epoch = 44; total train loss = 4652547.8750, train recon loss = 459993.1531, train kl loss = 52616.3469; total val loss = 939583.8511, val recon loss = 92903.1526 & val kl loss = 10552.3203
# epoch = 45; total train loss = 4651321.6597, train recon loss = 459856.9894, train kl loss = 52751.7612; total val loss = 940000.6196, val recon loss = 92950.8089 & val kl loss = 10492.5288
# epoch = 46; total train loss = 4649309.8569, train recon loss = 459660.1370, train kl loss = 52708.4857; total val loss = 940493.3184, val recon loss = 92986.4548 & val kl loss = 10628.7679
# epoch = 47; total train loss = 4647878.9858, train recon loss = 459507.8118, train kl loss = 52800.8687; total val loss = 940065.6855, val recon loss = 92950.0436 & val kl loss = 10565.2482
# epoch = 48; total train loss = 4647012.7051, train recon loss = 459417.2794, train kl loss = 52839.9064; total val loss = 940406.3301, val recon loss = 92999.0844 & val kl loss = 10415.4855
# epoch = 49; total train loss = 4645354.6665, train recon loss = 459241.0614, train kl loss = 52944.0572; total val loss = 939864.1772, val recon loss = 92933.1352 & val kl loss = 10532.8256
# epoch = 50; total train loss = 4643978.1436, train recon loss = 459095.9345, train kl loss = 53018.8051; total val loss = 940013.2100, val recon loss = 92942.9151 & val kl loss = 10584.0615
# epoch = 51; total train loss = 4642891.8804, train recon loss = 458984.6339, train kl loss = 53045.5380; total val loss = 939666.1577, val recon loss = 92907.6453 & val kl loss = 10589.7055
# epoch = 52; total train loss = 4641167.4155, train recon loss = 458801.7739, train kl loss = 53149.6674; total val loss = 939594.6494, val recon loss = 92878.3649 & val kl loss = 10811.0003
# epoch = 53; total train loss = 4639917.5796, train recon loss = 458664.0900, train kl loss = 53276.6797; total val loss = 939880.6489, val recon loss = 92919.7098 & val kl loss = 10683.5509
# epoch = 54; total train loss = 4638945.9287, train recon loss = 458564.0750, train kl loss = 53305.1821; total val loss = 939591.2236, val recon loss = 92869.7044 & val kl loss = 10894.1787
# epoch = 55; total train loss = 4637087.0923, train recon loss = 458368.2252, train kl loss = 53404.8374; total val loss = 940170.4805, val recon loss = 92972.1505 & val kl loss = 10448.9757
# epoch = 56; total train loss = 4635920.5225, train recon loss = 458243.5141, train kl loss = 53485.3724; total val loss = 939717.0332, val recon loss = 92894.8544 & val kl loss = 10768.4890
# epoch = 57; total train loss = 4635050.6157, train recon loss = 458152.5394, train kl loss = 53525.2245; total val loss = 939411.5273, val recon loss = 92846.0830 & val kl loss = 10950.6955
# epoch = 58; total train loss = 4633720.2681, train recon loss = 458015.0927, train kl loss = 53569.3347; total val loss = 939410.1475, val recon loss = 92878.4003 & val kl loss = 10626.1389
# epoch = 59; total train loss = 4632467.1558, train recon loss = 457882.2604, train kl loss = 53644.5393; total val loss = 939761.0996, val recon loss = 92916.9368 & val kl loss = 10591.7315
# epoch = 60; total train loss = 4631513.7217, train recon loss = 457783.3978, train kl loss = 53679.7291; total val loss = 939830.6494, val recon loss = 92901.1087 & val kl loss = 10819.5606
# epoch = 61; total train loss = 4629881.1455, train recon loss = 457614.1448, train kl loss = 53739.6937; total val loss = 940218.6182, val recon loss = 92939.6014 & val kl loss = 10822.6076
# epoch = 62; total train loss = 4628846.3774, train recon loss = 457511.5324, train kl loss = 53731.0517; total val loss = 939626.7578, val recon loss = 92867.8752 & val kl loss = 10948.0064
# epoch = 63; total train loss = 4627588.9414, train recon loss = 457376.3989, train kl loss = 53824.9478; total val loss = 939607.1738, val recon loss = 92895.4766 & val kl loss = 10652.4075
# epoch = 64; total train loss = 4627067.4014, train recon loss = 457315.6871, train kl loss = 53910.5326; total val loss = 939715.0029, val recon loss = 92910.2525 & val kl loss = 10612.4781
# epoch = 65; total train loss = 4625895.8887, train recon loss = 457202.5333, train kl loss = 53870.5576; total val loss = 940221.6562, val recon loss = 92927.9725 & val kl loss = 10941.9329
# epoch = 66; total train loss = 4624548.5034, train recon loss = 457062.7663, train kl loss = 53920.8389; total val loss = 940334.9175, val recon loss = 92927.3297 & val kl loss = 11061.6215
# epoch = 67; total train loss = 4623524.5234, train recon loss = 456954.6180, train kl loss = 53978.3402; total val loss = 940186.0112, val recon loss = 92936.4265 & val kl loss = 10821.7436
# epoch = 68; total train loss = 4622541.3823, train recon loss = 456852.6441, train kl loss = 54014.9385; total val loss = 941064.4824, val recon loss = 93022.3749 & val kl loss = 10840.7312
# epoch = 69; total train loss = 4621567.1772, train recon loss = 456751.7764, train kl loss = 54049.4212; total val loss = 939984.3169, val recon loss = 92914.1418 & val kl loss = 10842.9020
# epoch = 70; total train loss = 4620618.7275, train recon loss = 456652.8802, train kl loss = 54089.9175; total val loss = 940714.2212, val recon loss = 92986.4882 & val kl loss = 10849.3354
# epoch = 71; total train loss = 4618995.4902, train recon loss = 456485.3659, train kl loss = 54141.8262; total val loss = 940362.2793, val recon loss = 92970.5159 & val kl loss = 10657.1192
# epoch = 72; total train loss = 4618474.8662, train recon loss = 456431.5698, train kl loss = 54159.1752; total val loss = 940325.6475, val recon loss = 92958.4369 & val kl loss = 10741.2838
# epoch = 73; total train loss = 4617815.6084, train recon loss = 456357.9065, train kl loss = 54236.5538; total val loss = 940254.3613, val recon loss = 92954.8492 & val kl loss = 10705.8688
# epoch = 74; total train loss = 4617063.5903, train recon loss = 456281.3565, train kl loss = 54250.0220; total val loss = 940702.6807, val recon loss = 92982.7139 & val kl loss = 10875.5420
# epoch = 75; total train loss = 4616084.9146, train recon loss = 456179.0082, train kl loss = 54294.8251; total val loss = 941165.1934, val recon loss = 93023.0241 & val kl loss = 10934.9551
# epoch = 76; total train loss = 4615028.2026, train recon loss = 456066.5505, train kl loss = 54362.6997; total val loss = 940974.6650, val recon loss = 93019.7950 & val kl loss = 10776.7136
# epoch = 77; total train loss = 4614302.7930, train recon loss = 455991.2033, train kl loss = 54390.7547; total val loss = 940315.2812, val recon loss = 92960.6088 & val kl loss = 10709.1941
# epoch = 78; total train loss = 4613444.0649, train recon loss = 455904.7137, train kl loss = 54396.9272; total val loss = 940943.5469, val recon loss = 93007.4342 & val kl loss = 10869.2064
# epoch = 79; total train loss = 4612491.4243, train recon loss = 455798.5181, train kl loss = 54506.2449; total val loss = 940825.7388, val recon loss = 92985.1697 & val kl loss = 10974.0420
# epoch = 80; total train loss = 4611782.0161, train recon loss = 455724.1549, train kl loss = 54540.4698; total val loss = 941748.3081, val recon loss = 93099.4785 & val kl loss = 10753.5250
# epoch = 81; total train loss = 4610926.5029, train recon loss = 455639.7217, train kl loss = 54529.2809; total val loss = 941909.9663, val recon loss = 93084.2263 & val kl loss = 11067.7023
# epoch = 82; total train loss = 4610045.1406, train recon loss = 455537.7562, train kl loss = 54667.5780; total val loss = 941307.0273, val recon loss = 93035.3511 & val kl loss = 10953.5148
# epoch = 83; total train loss = 4609684.2954, train recon loss = 455498.7935, train kl loss = 54696.3584; total val loss = 941045.7202, val recon loss = 93024.0557 & val kl loss = 10805.1673
# epoch = 84; total train loss = 4608726.1465, train recon loss = 455404.5726, train kl loss = 54680.4341; total val loss = 941917.5625, val recon loss = 93112.7795 & val kl loss = 10789.7683
# epoch = 85; total train loss = 4607779.4575, train recon loss = 455301.3271, train kl loss = 54766.1903; total val loss = 942388.7354, val recon loss = 93157.3893 & val kl loss = 10814.8436
# epoch = 86; total train loss = 4607070.6729, train recon loss = 455225.3454, train kl loss = 54817.2268; total val loss = 942010.2988, val recon loss = 93099.2856 & val kl loss = 11017.4459
# epoch = 87; total train loss = 4606779.7612, train recon loss = 455194.1698, train kl loss = 54838.0560; total val loss = 943582.8267, val recon loss = 93245.8729 & val kl loss = 11124.0964
# epoch = 88; total train loss = 4605892.5918, train recon loss = 455100.8549, train kl loss = 54884.0529; total val loss = 941818.7969, val recon loss = 93065.4843 & val kl loss = 11163.9572
# epoch = 89; total train loss = 4605096.5469, train recon loss = 455014.1731, train kl loss = 54954.8096; total val loss = 941411.9429, val recon loss = 93038.5214 & val kl loss = 11026.7291
# epoch = 90; total train loss = 4604493.5801, train recon loss = 454950.8368, train kl loss = 54985.2095; total val loss = 941785.5659, val recon loss = 93090.5248 & val kl loss = 10880.3156
# epoch = 91; total train loss = 4603905.9141, train recon loss = 454888.2951, train kl loss = 55022.9705; total val loss = 942590.2974, val recon loss = 93148.3284 & val kl loss = 11107.0154
# epoch = 92; total train loss = 4603293.5947, train recon loss = 454815.6261, train kl loss = 55137.3331; total val loss = 941683.7104, val recon loss = 93078.3890 & val kl loss = 10899.8203
# epoch = 93; total train loss = 4602739.2388, train recon loss = 454763.9586, train kl loss = 55099.6528; total val loss = 942073.2896, val recon loss = 93089.7401 & val kl loss = 11175.8872
# epoch = 94; total train loss = 4602003.8936, train recon loss = 454684.5350, train kl loss = 55158.5392; total val loss = 942129.3691, val recon loss = 93113.7068 & val kl loss = 10992.3010
# epoch = 95; total train loss = 4601327.9565, train recon loss = 454614.6497, train kl loss = 55181.4592; total val loss = 942814.1270, val recon loss = 93161.0101 & val kl loss = 11204.0239
# epoch = 96; total train loss = 4601050.0220, train recon loss = 454579.2760, train kl loss = 55257.2552; total val loss = 942111.2842, val recon loss = 93099.7080 & val kl loss = 11114.2048
# epoch = 97; total train loss = 4600144.0254, train recon loss = 454488.2701, train kl loss = 55261.3221; total val loss = 942456.3003, val recon loss = 93143.3993 & val kl loss = 11022.3033
# epoch = 98; total train loss = 4599723.0293, train recon loss = 454441.8922, train kl loss = 55304.1070; total val loss = 941858.0581, val recon loss = 93088.4420 & val kl loss = 10973.6394
# epoch = 99; total train loss = 4599238.8926, train recon loss = 454383.9166, train kl loss = 55399.7317; total val loss = 944015.2622, val recon loss = 93266.5297 & val kl loss = 11349.9648
# epoch = 100; total train loss = 4598565.9927, train recon loss = 454314.7892, train kl loss = 55418.1067; total val loss = 942925.0078, val recon loss = 93181.2479 & val kl loss = 11112.5314
# epoch = 101; total train loss = 4598254.9204, train recon loss = 454276.5638, train kl loss = 55489.2764; total val loss = 943040.9644, val recon loss = 93196.9734 & val kl loss = 11071.2320
# epoch = 102; total train loss = 4596970.8096, train recon loss = 454150.5366, train kl loss = 55465.4422; total val loss = 943182.5327, val recon loss = 93208.5644 & val kl loss = 11096.8893
# epoch = 103; total train loss = 4597159.9644, train recon loss = 454166.2292, train kl loss = 55497.6748; total val loss = 943180.7778, val recon loss = 93197.5391 & val kl loss = 11205.3850
# epoch = 104; total train loss = 4596377.4727, train recon loss = 454076.0464, train kl loss = 55617.0079; total val loss = 944465.0928, val recon loss = 93311.0884 & val kl loss = 11354.2068
# epoch = 105; total train loss = 4596221.1572, train recon loss = 454061.6772, train kl loss = 55604.3812; total val loss = 943276.4731, val recon loss = 93217.5598 & val kl loss = 11100.8765
# epoch = 106; total train loss = 4595363.3301, train recon loss = 453972.1624, train kl loss = 55641.7001; total val loss = 943247.5459, val recon loss = 93191.8103 & val kl loss = 11329.4398
# epoch = 107; total train loss = 4594985.4873, train recon loss = 453926.7841, train kl loss = 55717.6556; total val loss = 942470.0513, val recon loss = 93146.5182 & val kl loss = 11004.8658
# epoch = 108; total train loss = 4594620.3691, train recon loss = 453888.8716, train kl loss = 55731.6433; total val loss = 943522.9028, val recon loss = 93228.7154 & val kl loss = 11235.7528
# epoch = 109; total train loss = 4594145.9614, train recon loss = 453841.5245, train kl loss = 55730.7023; total val loss = 943115.8154, val recon loss = 93202.3422 & val kl loss = 11092.3901
# epoch = 110; total train loss = 4593702.9810, train recon loss = 453787.9440, train kl loss = 55823.5554; total val loss = 943258.6426, val recon loss = 93198.9521 & val kl loss = 11269.1203
# epoch = 111; total train loss = 4593402.1611, train recon loss = 453758.9913, train kl loss = 55812.2479; total val loss = 943163.7607, val recon loss = 93199.2424 & val kl loss = 11171.3319
# epoch = 112; total train loss = 4592629.5352, train recon loss = 453674.3639, train kl loss = 55885.9045; total val loss = 942933.9399, val recon loss = 93188.5017 & val kl loss = 11048.9236
# epoch = 113; total train loss = 4591886.7988, train recon loss = 453599.3520, train kl loss = 55893.2808; total val loss = 943536.3892, val recon loss = 93240.6790 & val kl loss = 11129.6025
# epoch = 114; total train loss = 4591806.5791, train recon loss = 453583.1724, train kl loss = 55974.8599; total val loss = 943775.7944, val recon loss = 93248.0236 & val kl loss = 11295.5549
# epoch = 115; total train loss = 4591179.0732, train recon loss = 453519.4728, train kl loss = 55984.3408; total val loss = 945222.4146, val recon loss = 93402.2925 & val kl loss = 11199.4838
# epoch = 116; total train loss = 4591006.9414, train recon loss = 453498.5240, train kl loss = 56021.6896; total val loss = 944484.7515, val recon loss = 93318.3190 & val kl loss = 11301.5598
# epoch = 117; total train loss = 4590452.5190, train recon loss = 453438.0020, train kl loss = 56072.5005; total val loss = 943108.5410, val recon loss = 93187.7995 & val kl loss = 11230.5442
# epoch = 118; total train loss = 4589932.8018, train recon loss = 453381.2382, train kl loss = 56120.4097; total val loss = 943904.6196, val recon loss = 93276.6273 & val kl loss = 11138.3506
# epoch = 119; total train loss = 4589581.1484, train recon loss = 453347.0551, train kl loss = 56110.5987; total val loss = 943195.6812, val recon loss = 93205.7908 & val kl loss = 11137.7715
# epoch = 120; total train loss = 4589122.0181, train recon loss = 453297.1479, train kl loss = 56150.5301; total val loss = 943934.3716, val recon loss = 93276.7914 & val kl loss = 11166.4535
# epoch = 121; total train loss = 4588798.0127, train recon loss = 453256.7631, train kl loss = 56230.3849; total val loss = 943477.7676, val recon loss = 93217.7458 & val kl loss = 11300.3116
# epoch = 122; total train loss = 4588652.8296, train recon loss = 453241.4597, train kl loss = 56238.2350; total val loss = 944335.0254, val recon loss = 93292.7741 & val kl loss = 11407.2863
# epoch = 123; total train loss = 4587909.5742, train recon loss = 453167.0565, train kl loss = 56239.0145; total val loss = 944575.0586, val recon loss = 93304.4387 & val kl loss = 11530.6702
# epoch = 124; total train loss = 4587568.4292, train recon loss = 453123.5012, train kl loss = 56333.4109; total val loss = 945935.3735, val recon loss = 93441.8824 & val kl loss = 11516.5460
# epoch = 125; total train loss = 4587110.1934, train recon loss = 453076.7990, train kl loss = 56342.2068; total val loss = 944383.9448, val recon loss = 93308.0110 & val kl loss = 11303.8372
# epoch = 126; total train loss = 4586982.9956, train recon loss = 453063.3969, train kl loss = 56349.0330; total val loss = 944626.9131, val recon loss = 93333.7339 & val kl loss = 11289.5787
# epoch = 127; total train loss = 4586805.5420, train recon loss = 453044.6376, train kl loss = 56359.1704; total val loss = 944906.2197, val recon loss = 93357.0411 & val kl loss = 11335.8107
# epoch = 128; total train loss = 4586091.8340, train recon loss = 452968.6117, train kl loss = 56405.7224; total val loss = 943601.9043, val recon loss = 93244.8762 & val kl loss = 11153.1370
# epoch = 129; total train loss = 4585986.3765, train recon loss = 452960.1671, train kl loss = 56384.7140; total val loss = 944261.0518, val recon loss = 93285.8637 & val kl loss = 11402.4135
# epoch = 130; total train loss = 4585470.7178, train recon loss = 452898.7674, train kl loss = 56483.0453; total val loss = 944539.3955, val recon loss = 93317.1846 & val kl loss = 11367.5460
# epoch = 131; total train loss = 4584680.0786, train recon loss = 452815.3824, train kl loss = 56526.2601; total val loss = 943927.8945, val recon loss = 93260.6426 & val kl loss = 11321.4682
# epoch = 132; total train loss = 4584731.4385, train recon loss = 452823.0151, train kl loss = 56501.2919; total val loss = 944847.6113, val recon loss = 93366.8772 & val kl loss = 11178.8402
# epoch = 133; total train loss = 4584507.0410, train recon loss = 452793.7933, train kl loss = 56569.1044; total val loss = 944500.0654, val recon loss = 93333.2512 & val kl loss = 11167.5471
# epoch = 134; total train loss = 4584097.0366, train recon loss = 452749.6218, train kl loss = 56600.8146; total val loss = 944736.5977, val recon loss = 93340.3327 & val kl loss = 11333.2755
# epoch = 135; total train loss = 4583776.8730, train recon loss = 452716.1370, train kl loss = 56615.5132; total val loss = 944331.6294, val recon loss = 93289.3002 & val kl loss = 11438.6239
# epoch = 136; total train loss = 4583429.3271, train recon loss = 452675.9924, train kl loss = 56669.4014; total val loss = 944711.5591, val recon loss = 93338.0370 & val kl loss = 11331.1888
# epoch = 137; total train loss = 4583437.1006, train recon loss = 452677.7819, train kl loss = 56659.2848; total val loss = 945148.5303, val recon loss = 93364.5646 & val kl loss = 11502.8823
# epoch = 138; total train loss = 4582895.3452, train recon loss = 452617.5833, train kl loss = 56719.5190; total val loss = 944764.9038, val recon loss = 93342.0684 & val kl loss = 11344.2184
# epoch = 139; total train loss = 4582535.4429, train recon loss = 452579.6703, train kl loss = 56738.7333; total val loss = 945704.3193, val recon loss = 93431.7253 & val kl loss = 11387.0669
# epoch = 140; total train loss = 4582042.2114, train recon loss = 452525.0462, train kl loss = 56791.7441; total val loss = 945461.4912, val recon loss = 93387.0868 & val kl loss = 11590.6256
# epoch = 141; total train loss = 4582088.8237, train recon loss = 452529.2678, train kl loss = 56796.1463; total val loss = 944953.4160, val recon loss = 93380.3329 & val kl loss = 11150.0851
# epoch = 142; total train loss = 4581345.7451, train recon loss = 452450.5557, train kl loss = 56840.1869; total val loss = 946707.7417, val recon loss = 93513.9221 & val kl loss = 11568.5249
# epoch = 143; total train loss = 4581595.3330, train recon loss = 452475.0672, train kl loss = 56844.6678; total val loss = 945040.4341, val recon loss = 93358.5385 & val kl loss = 11455.0510
# epoch = 144; total train loss = 4580940.9502, train recon loss = 452405.2004, train kl loss = 56888.9463; total val loss = 944543.8364, val recon loss = 93308.2809 & val kl loss = 11461.0272
# epoch = 145; total train loss = 4580090.6836, train recon loss = 452315.5506, train kl loss = 56935.1873; total val loss = 947244.7861, val recon loss = 93573.7169 & val kl loss = 11507.6133
# epoch = 146; total train loss = 4580486.1138, train recon loss = 452356.3731, train kl loss = 56922.3887; total val loss = 944725.5942, val recon loss = 93340.0690 & val kl loss = 11324.9066
# epoch = 147; total train loss = 4580280.1455, train recon loss = 452334.3719, train kl loss = 56936.4251; total val loss = 944677.6611, val recon loss = 93324.7073 & val kl loss = 11430.5893
# epoch = 148; total train loss = 4579865.7163, train recon loss = 452290.5319, train kl loss = 56960.4052; total val loss = 944925.0708, val recon loss = 93342.4443 & val kl loss = 11500.6263
# epoch = 149; total train loss = 4579300.5527, train recon loss = 452230.9666, train kl loss = 56990.8869; total val loss = 945040.1616, val recon loss = 93364.0871 & val kl loss = 11399.2899
# epoch = 150; total train loss = 4579579.0933, train recon loss = 452255.8583, train kl loss = 57020.5153; total val loss = 945614.2920, val recon loss = 93410.4057 & val kl loss = 11510.2377
# epoch = 151; total train loss = 4578865.0493, train recon loss = 452181.9774, train kl loss = 57045.2745; total val loss = 944495.7520, val recon loss = 93324.8647 & val kl loss = 11247.1059
# epoch = 152; total train loss = 4578863.0908, train recon loss = 452179.2767, train kl loss = 57070.3271; total val loss = 945502.4575, val recon loss = 93404.0941 & val kl loss = 11461.5121
# epoch = 153; total train loss = 4578297.4497, train recon loss = 452120.2909, train kl loss = 57094.5407; total val loss = 944952.5879, val recon loss = 93365.3904 & val kl loss = 11298.6853
# epoch = 154; total train loss = 4578047.9067, train recon loss = 452093.3116, train kl loss = 57114.7910; total val loss = 944493.7749, val recon loss = 93296.6481 & val kl loss = 11527.2967
# epoch = 155; total train loss = 4577709.3076, train recon loss = 452057.2827, train kl loss = 57136.4744; total val loss = 945701.6108, val recon loss = 93427.8310 & val kl loss = 11423.3026
# epoch = 156; total train loss = 4577859.0127, train recon loss = 452066.4536, train kl loss = 57194.4674; total val loss = 946520.9575, val recon loss = 93465.0154 & val kl loss = 11870.8078
# epoch = 157; total train loss = 4577277.2798, train recon loss = 452008.2392, train kl loss = 57194.8822; total val loss = 945004.5527, val recon loss = 93354.5493 & val kl loss = 11459.0574
# epoch = 158; total train loss = 4577205.1289, train recon loss = 452000.8738, train kl loss = 57196.3917; total val loss = 944841.7466, val recon loss = 93353.5043 & val kl loss = 11306.7035
# epoch = 159; total train loss = 4577039.0312, train recon loss = 451981.9579, train kl loss = 57219.4463; total val loss = 945738.9048, val recon loss = 93446.9865 & val kl loss = 11269.0398
# epoch = 160; total train loss = 4576569.3081, train recon loss = 451932.3793, train kl loss = 57245.5264; total val loss = 945633.6279, val recon loss = 93430.3499 & val kl loss = 11330.1310
# epoch = 161; total train loss = 4576041.1943, train recon loss = 451876.7553, train kl loss = 57273.6546; total val loss = 944721.6206, val recon loss = 93327.0359 & val kl loss = 11451.2596
# epoch = 162; total train loss = 4576089.0122, train recon loss = 451880.4083, train kl loss = 57284.9294; total val loss = 945351.4541, val recon loss = 93383.7379 & val kl loss = 11514.0756
# epoch = 163; total train loss = 4576052.3389, train recon loss = 451873.4815, train kl loss = 57317.5328; total val loss = 944833.8594, val recon loss = 93318.2260 & val kl loss = 11651.6047
# epoch = 164; total train loss = 4575855.1055, train recon loss = 451851.2706, train kl loss = 57342.4136; total val loss = 944915.3594, val recon loss = 93341.1497 & val kl loss = 11503.8614
# epoch = 165; total train loss = 4575352.4854, train recon loss = 451802.5200, train kl loss = 57327.2903; total val loss = 944118.5527, val recon loss = 93283.5106 & val kl loss = 11283.4473
# epoch = 166; total train loss = 4575250.9668, train recon loss = 451790.2188, train kl loss = 57348.7738; total val loss = 945166.2026, val recon loss = 93359.0262 & val kl loss = 11575.9427
# epoch = 167; total train loss = 4574878.3628, train recon loss = 451747.5979, train kl loss = 57402.3907; total val loss = 945087.9990, val recon loss = 93354.2912 & val kl loss = 11545.0920
# epoch = 168; total train loss = 4575004.5674, train recon loss = 451761.1342, train kl loss = 57393.2249; total val loss = 944971.7007, val recon loss = 93353.1332 & val kl loss = 11440.3681
# epoch = 169; total train loss = 4574388.6021, train recon loss = 451695.0829, train kl loss = 57437.7713; total val loss = 945208.4937, val recon loss = 93382.6893 & val kl loss = 11381.5984
# epoch = 170; total train loss = 4574387.7661, train recon loss = 451690.0588, train kl loss = 57487.1816; total val loss = 945476.8389, val recon loss = 93410.7001 & val kl loss = 11369.8349
# epoch = 171; total train loss = 4573944.9746, train recon loss = 451646.2420, train kl loss = 57482.5642; total val loss = 945932.8340, val recon loss = 93446.6645 & val kl loss = 11466.1909
# epoch = 172; total train loss = 4574122.8560, train recon loss = 451662.7738, train kl loss = 57495.1236; total val loss = 945329.5986, val recon loss = 93392.1360 & val kl loss = 11408.2362
# epoch = 173; total train loss = 4573907.1299, train recon loss = 451634.6691, train kl loss = 57560.4384; total val loss = 945631.7705, val recon loss = 93398.5458 & val kl loss = 11646.3102
# epoch = 174; total train loss = 4573425.1138, train recon loss = 451590.9346, train kl loss = 57515.7642; total val loss = 945713.6836, val recon loss = 93418.8796 & val kl loss = 11524.8908
# epoch = 175; total train loss = 4573293.3057, train recon loss = 451572.3464, train kl loss = 57569.8288; total val loss = 946722.9565, val recon loss = 93510.1973 & val kl loss = 11620.9861
# epoch = 176; total train loss = 4573218.7393, train recon loss = 451561.5160, train kl loss = 57603.5854; total val loss = 946260.9780, val recon loss = 93471.2827 & val kl loss = 11548.1491
# epoch = 177; total train loss = 4572928.4326, train recon loss = 451528.5112, train kl loss = 57643.3213; total val loss = 945245.6431, val recon loss = 93369.1813 & val kl loss = 11553.8298
# epoch = 178; total train loss = 4572643.9346, train recon loss = 451501.6041, train kl loss = 57627.8890; total val loss = 945691.4053, val recon loss = 93424.9780 & val kl loss = 11441.6223
# epoch = 179; total train loss = 4572665.7383, train recon loss = 451503.0679, train kl loss = 57635.0632; total val loss = 946398.9951, val recon loss = 93485.3678 & val kl loss = 11545.3142
# epoch = 180; total train loss = 4572470.5649, train recon loss = 451481.8701, train kl loss = 57651.8577; total val loss = 947362.8354, val recon loss = 93569.7411 & val kl loss = 11665.4244
# epoch = 181; total train loss = 4572181.4424, train recon loss = 451452.6169, train kl loss = 57655.2801; total val loss = 946477.0449, val recon loss = 93468.7952 & val kl loss = 11789.0952
# epoch = 182; total train loss = 4571622.0249, train recon loss = 451393.3335, train kl loss = 57688.7029; total val loss = 945905.3604, val recon loss = 93424.2071 & val kl loss = 11663.2889
# epoch = 183; total train loss = 4571779.4395, train recon loss = 451405.0166, train kl loss = 57729.2714; total val loss = 945397.8706, val recon loss = 93384.9351 & val kl loss = 11548.5153
# epoch = 184; total train loss = 4571449.7222, train recon loss = 451364.7539, train kl loss = 57802.1853; total val loss = 946664.1743, val recon loss = 93516.8364 & val kl loss = 11495.8096
# epoch = 185; total train loss = 4571369.4761, train recon loss = 451363.6531, train kl loss = 57732.9421; total val loss = 946163.9902, val recon loss = 93460.4002 & val kl loss = 11559.9864
# epoch = 186; total train loss = 4571350.1235, train recon loss = 451356.1307, train kl loss = 57788.8069; total val loss = 945413.7700, val recon loss = 93383.5057 & val kl loss = 11578.7122
# epoch = 187; total train loss = 4570972.0112, train recon loss = 451320.2059, train kl loss = 57769.9534; total val loss = 944667.6133, val recon loss = 93316.8327 & val kl loss = 11499.2849
# epoch = 188; total train loss = 4570907.6572, train recon loss = 451317.2025, train kl loss = 57735.6212; total val loss = 946104.4180, val recon loss = 93462.6722 & val kl loss = 11477.6975
# epoch = 189; total train loss = 4570401.3076, train recon loss = 451262.1487, train kl loss = 57779.8274; total val loss = 947236.1641, val recon loss = 93552.3268 & val kl loss = 11712.8942
# epoch = 190; total train loss = 4570261.9434, train recon loss = 451243.8668, train kl loss = 57823.2721; total val loss = 947029.6299, val recon loss = 93535.2645 & val kl loss = 11676.9863
# epoch = 191; total train loss = 4570252.1011, train recon loss = 451235.0652, train kl loss = 57901.4546; total val loss = 947413.3530, val recon loss = 93573.2416 & val kl loss = 11680.9393
# epoch = 192; total train loss = 4569912.2393, train recon loss = 451203.3277, train kl loss = 57878.9674; total val loss = 947443.2441, val recon loss = 93596.1501 & val kl loss = 11481.7416
# epoch = 193; total train loss = 4570160.8164, train recon loss = 451228.8326, train kl loss = 57872.4895; total val loss = 946914.3066, val recon loss = 93518.5374 & val kl loss = 11728.9342
# epoch = 194; total train loss = 4569655.5161, train recon loss = 451176.5504, train kl loss = 57890.0081; total val loss = 947784.8232, val recon loss = 93611.0812 & val kl loss = 11674.0082
# epoch = 195; total train loss = 4569652.1592, train recon loss = 451174.1300, train kl loss = 57910.8610; total val loss = 945937.9180, val recon loss = 93415.2198 & val kl loss = 11785.7205
# epoch = 196; total train loss = 4569231.0176, train recon loss = 451130.0154, train kl loss = 57930.8698; total val loss = 946774.5449, val recon loss = 93511.5737 & val kl loss = 11658.8021
# epoch = 197; total train loss = 4568904.1968, train recon loss = 451097.8058, train kl loss = 57926.1390; total val loss = 947807.1567, val recon loss = 93617.2485 & val kl loss = 11634.6724
# epoch = 198; total train loss = 4568826.2524, train recon loss = 451085.6213, train kl loss = 57970.0376; total val loss = 946419.0371, val recon loss = 93482.5439 & val kl loss = 11593.5988
# epoch = 199; total train loss = 4568788.4878, train recon loss = 451088.1555, train kl loss = 57906.9289; total val loss = 945721.2300, val recon loss = 93413.9433 & val kl loss = 11581.7956
# epoch = 200; total train loss = 4568720.3086, train recon loss = 451074.5933, train kl loss = 57974.3811; total val loss = 946586.0459, val recon loss = 93508.5712 & val kl loss = 11500.3337
# epoch = 201; total train loss = 4568347.7959, train recon loss = 451034.5051, train kl loss = 58002.7463; total val loss = 946266.2329, val recon loss = 93461.8535 & val kl loss = 11647.6989
# epoch = 202; total train loss = 4568015.2983, train recon loss = 450998.9683, train kl loss = 58025.6049; total val loss = 946433.7559, val recon loss = 93485.8839 & val kl loss = 11574.9181
# epoch = 203; total train loss = 4568291.7969, train recon loss = 451027.0165, train kl loss = 58021.6301; total val loss = 946423.1714, val recon loss = 93459.3434 & val kl loss = 11829.7403
# epoch = 204; total train loss = 4567891.3462, train recon loss = 450982.4772, train kl loss = 58066.5722; total val loss = 946500.0942, val recon loss = 93475.6572 & val kl loss = 11743.5219
# epoch = 205; total train loss = 4567989.6592, train recon loss = 450996.2650, train kl loss = 58027.0112; total val loss = 946977.0835, val recon loss = 93534.5717 & val kl loss = 11631.3664
# epoch = 206; total train loss = 4567684.1934, train recon loss = 450958.8557, train kl loss = 58095.6446; total val loss = 946717.1572, val recon loss = 93516.0969 & val kl loss = 11556.1872
# epoch = 207; total train loss = 4567429.4014, train recon loss = 450936.0801, train kl loss = 58068.6150; total val loss = 946049.0557, val recon loss = 93455.6343 & val kl loss = 11492.7137
# epoch = 208; total train loss = 4567224.1851, train recon loss = 450911.8549, train kl loss = 58105.6333; total val loss = 946537.6611, val recon loss = 93485.8711 & val kl loss = 11678.9497
# epoch = 209; total train loss = 4567013.5938, train recon loss = 450883.5526, train kl loss = 58178.0659; total val loss = 946499.2241, val recon loss = 93478.1800 & val kl loss = 11717.4290
# epoch = 210; total train loss = 4567399.7358, train recon loss = 450924.1841, train kl loss = 58157.9011; total val loss = 945594.7788, val recon loss = 93399.1868 & val kl loss = 11602.9129
# epoch = 211; total train loss = 4567064.6270, train recon loss = 450888.4489, train kl loss = 58180.1394; total val loss = 947138.6426, val recon loss = 93548.4188 & val kl loss = 11654.4555
# epoch = 212; total train loss = 4566772.1226, train recon loss = 450862.1159, train kl loss = 58150.9598; total val loss = 947119.3081, val recon loss = 93541.2629 & val kl loss = 11706.6776
# epoch = 213; total train loss = 4566596.1660, train recon loss = 450840.2845, train kl loss = 58193.3159; total val loss = 946973.2197, val recon loss = 93539.6768 & val kl loss = 11576.4521
# epoch = 214; total train loss = 4566476.4346, train recon loss = 450831.0878, train kl loss = 58165.5606; total val loss = 946756.0752, val recon loss = 93536.4214 & val kl loss = 11391.8614
# epoch = 215; total train loss = 4566075.3457, train recon loss = 450785.7900, train kl loss = 58217.4541; total val loss = 947715.1992, val recon loss = 93593.1915 & val kl loss = 11783.2818
# epoch = 216; total train loss = 4566336.8447, train recon loss = 450807.5096, train kl loss = 58261.7536; total val loss = 947525.0005, val recon loss = 93581.2118 & val kl loss = 11712.8849
# epoch = 217; total train loss = 4565899.8159, train recon loss = 450763.5123, train kl loss = 58264.6891; total val loss = 948340.3027, val recon loss = 93667.6876 & val kl loss = 11663.4264
# epoch = 218; total train loss = 4566048.6362, train recon loss = 450778.0626, train kl loss = 58268.0156; total val loss = 947334.4307, val recon loss = 93560.8816 & val kl loss = 11725.6143
# epoch = 219; total train loss = 4565562.8481, train recon loss = 450726.2102, train kl loss = 58300.7423; total val loss = 946875.5044, val recon loss = 93527.2196 & val kl loss = 11603.3113
# epoch = 220; total train loss = 4565401.2319, train recon loss = 450706.2651, train kl loss = 58338.5769; total val loss = 947777.6572, val recon loss = 93611.5113 & val kl loss = 11662.5481
# epoch = 221; total train loss = 4565190.6245, train recon loss = 450691.3943, train kl loss = 58276.6809; total val loss = 947606.8506, val recon loss = 93591.9921 & val kl loss = 11686.9310
# epoch = 222; total train loss = 4565427.0234, train recon loss = 450713.8021, train kl loss = 58289.0090; total val loss = 947644.7183, val recon loss = 93593.1545 & val kl loss = 11713.1729
# epoch = 223; total train loss = 4564671.6045, train recon loss = 450634.7475, train kl loss = 58324.1271; total val loss = 946985.3955, val recon loss = 93528.8019 & val kl loss = 11697.3731
# epoch = 224; total train loss = 4565114.9390, train recon loss = 450677.8342, train kl loss = 58336.5788; total val loss = 946661.2397, val recon loss = 93495.0344 & val kl loss = 11710.9001
# epoch = 225; total train loss = 4564726.5210, train recon loss = 450637.2218, train kl loss = 58354.3000; total val loss = 946570.1655, val recon loss = 93474.3745 & val kl loss = 11826.4224
# epoch = 226; total train loss = 4564830.2148, train recon loss = 450647.6407, train kl loss = 58353.8011; total val loss = 947073.4116, val recon loss = 93516.0587 & val kl loss = 11912.8241
# epoch = 227; total train loss = 4564672.9863, train recon loss = 450630.7505, train kl loss = 58365.4861; total val loss = 948549.4092, val recon loss = 93659.8321 & val kl loss = 11951.0914
# epoch = 228; total train loss = 4563989.1675, train recon loss = 450560.1289, train kl loss = 58387.8831; total val loss = 946850.0864, val recon loss = 93507.7315 & val kl loss = 11772.7739
# epoch = 229; total train loss = 4564164.9443, train recon loss = 450579.1704, train kl loss = 58373.2448; total val loss = 947258.7212, val recon loss = 93551.4698 & val kl loss = 11744.0237
# epoch = 230; total train loss = 4564278.4004, train recon loss = 450585.7412, train kl loss = 58420.9876; total val loss = 947833.5171, val recon loss = 93592.3522 & val kl loss = 11909.9953
# epoch = 231; total train loss = 4563893.3838, train recon loss = 450545.5325, train kl loss = 58438.0547; total val loss = 947520.2954, val recon loss = 93565.5187 & val kl loss = 11865.1052
# epoch = 232; total train loss = 4563889.2441, train recon loss = 450548.1906, train kl loss = 58407.3372; total val loss = 947483.3594, val recon loss = 93566.8629 & val kl loss = 11814.7304
# epoch = 233; total train loss = 4563709.8887, train recon loss = 450527.4974, train kl loss = 58434.9216; total val loss = 947205.3335, val recon loss = 93563.5944 & val kl loss = 11569.3910
# epoch = 234; total train loss = 4563358.1602, train recon loss = 450491.9767, train kl loss = 58438.3930; total val loss = 948302.4868, val recon loss = 93637.5543 & val kl loss = 11926.9445
# epoch = 235; total train loss = 4563416.5439, train recon loss = 450492.3007, train kl loss = 58493.5249; total val loss = 946955.1606, val recon loss = 93513.1897 & val kl loss = 11823.2614
# epoch = 236; total train loss = 4563039.5439, train recon loss = 450452.9229, train kl loss = 58510.3133; total val loss = 946556.8594, val recon loss = 93509.0193 & val kl loss = 11466.6683
# epoch = 237; total train loss = 4563362.4209, train recon loss = 450486.2346, train kl loss = 58500.0763; total val loss = 946129.4077, val recon loss = 93454.8704 & val kl loss = 11580.7064
# epoch = 238; total train loss = 4563127.0957, train recon loss = 450460.5477, train kl loss = 58521.6190; total val loss = 948277.4976, val recon loss = 93645.3627 & val kl loss = 11823.8653
# epoch = 239; total train loss = 4562782.5127, train recon loss = 450425.1730, train kl loss = 58530.7829; total val loss = 948510.1304, val recon loss = 93677.2549 & val kl loss = 11737.5792
# epoch = 240; total train loss = 4563189.9004, train recon loss = 450462.6788, train kl loss = 58563.1073; total val loss = 947785.4292, val recon loss = 93627.9343 & val kl loss = 11506.0871
# epoch = 241; total train loss = 4562772.7520, train recon loss = 450422.8516, train kl loss = 58544.2272; total val loss = 948633.3384, val recon loss = 93684.9126 & val kl loss = 11784.2129
# epoch = 242; total train loss = 4562518.8438, train recon loss = 450393.2739, train kl loss = 58586.1101; total val loss = 948247.6387, val recon loss = 93646.0380 & val kl loss = 11787.2540
# epoch = 243; total train loss = 4562570.9551, train recon loss = 450393.6373, train kl loss = 58634.5809; total val loss = 947622.4067, val recon loss = 93589.5095 & val kl loss = 11727.3145
# epoch = 244; total train loss = 4562220.2163, train recon loss = 450362.8312, train kl loss = 58591.9103; total val loss = 949198.4600, val recon loss = 93742.4926 & val kl loss = 11773.5326
# epoch = 245; total train loss = 4562341.2896, train recon loss = 450374.6683, train kl loss = 58594.6097; total val loss = 948114.9727, val recon loss = 93627.6984 & val kl loss = 11837.9883
# epoch = 246; total train loss = 4562179.0571, train recon loss = 450352.5566, train kl loss = 58653.4875; total val loss = 947247.4390, val recon loss = 93558.6050 & val kl loss = 11661.3890
# epoch = 247; total train loss = 4562369.3130, train recon loss = 450373.4483, train kl loss = 58634.8274; total val loss = 947840.4478, val recon loss = 93608.7793 & val kl loss = 11752.6521
# epoch = 248; total train loss = 4561628.6934, train recon loss = 450295.3281, train kl loss = 58675.4223; total val loss = 946552.3257, val recon loss = 93492.9532 & val kl loss = 11622.7923
# epoch = 249; total train loss = 4561623.9321, train recon loss = 450299.9342, train kl loss = 58624.6023; total val loss = 948559.9702, val recon loss = 93676.1799 & val kl loss = 11798.1689
# epoch = 250; total train loss = 4561670.7295, train recon loss = 450299.1758, train kl loss = 58678.9663; total val loss = 947800.2393, val recon loss = 93595.4111 & val kl loss = 11846.1330
# epoch = 251; total train loss = 4561375.1504, train recon loss = 450269.6799, train kl loss = 58678.3589; total val loss = 946681.2720, val recon loss = 93504.9763 & val kl loss = 11631.5109
# ...
# epoch = 418; total train loss = 4549314.7720, train recon loss = 448926.5466, train kl loss = 60049.3096; total val loss = 950827.3662, val recon loss = 93869.3869 & val kl loss = 12133.4945
# epoch = 419; total train loss = 4548936.2246, train recon loss = 448893.6516, train kl loss = 59999.7043; total val loss = 951761.1431, val recon loss = 93952.9506 & val kl loss = 12231.6374
# epoch = 420; total train loss = 4549240.3018, train recon loss = 448917.3896, train kl loss = 60066.4113; total val loss = 948885.3486, val recon loss = 93681.5707 & val kl loss = 12069.6425
# epoch = 421; total train loss = 4548849.2676, train recon loss = 448875.5220, train kl loss = 60094.0508; total val loss = 949222.5396, val recon loss = 93729.3950 & val kl loss = 11928.5862
# epoch = 422; total train loss = 4549010.9424, train recon loss = 448898.0174, train kl loss = 60030.7619; total val loss = 950889.2041, val recon loss = 93898.5616 & val kl loss = 11903.5871
# epoch = 423; total train loss = 4548746.1885, train recon loss = 448868.7082, train kl loss = 60059.1067; total val loss = 950728.9580, val recon loss = 93856.1242 & val kl loss = 12167.7133
# epoch = 424; total train loss = 4548960.8169, train recon loss = 448889.8539, train kl loss = 60062.2752; total val loss = 950284.9360, val recon loss = 93791.0218 & val kl loss = 12374.7186
# epoch = 425; total train loss = 4548895.1309, train recon loss = 448880.5408, train kl loss = 60089.7196; total val loss = 948979.3750, val recon loss = 93702.5773 & val kl loss = 11953.6002
# epoch = 426; total train loss = 4548708.9629, train recon loss = 448864.7248, train kl loss = 60061.7207; total val loss = 950075.8687, val recon loss = 93803.5207 & val kl loss = 12040.6680
# epoch = 427; total train loss = 4548867.4976, train recon loss = 448878.7591, train kl loss = 60079.9130; total val loss = 949759.3765, val recon loss = 93744.5192 & val kl loss = 12314.1839
# epoch = 428; total train loss = 4548459.3477, train recon loss = 448836.3251, train kl loss = 60096.0889; total val loss = 949826.2046, val recon loss = 93761.7909 & val kl loss = 12208.2939
# epoch = 429; total train loss = 4548499.1978, train recon loss = 448842.3110, train kl loss = 60076.0920; total val loss = 949560.0571, val recon loss = 93757.2602 & val kl loss = 11987.4581
# epoch = 430; total train loss = 4548370.9946, train recon loss = 448823.9900, train kl loss = 60131.0993; total val loss = 950189.7144, val recon loss = 93819.9840 & val kl loss = 11989.8729
# epoch = 431; total train loss = 4548467.0923, train recon loss = 448837.8312, train kl loss = 60088.7821; total val loss = 950369.0391, val recon loss = 93820.1519 & val kl loss = 12167.5201
# epoch = 432; total train loss = 4548474.4492, train recon loss = 448839.0833, train kl loss = 60083.6219; total val loss = 948178.5483, val recon loss = 93619.3897 & val kl loss = 11984.6533
# epoch = 433; total train loss = 4548210.9487, train recon loss = 448809.7101, train kl loss = 60113.8446; total val loss = 949795.4502, val recon loss = 93779.4054 & val kl loss = 12001.3985
# epoch = 434; total train loss = 4548264.6069, train recon loss = 448811.6212, train kl loss = 60148.4029; total val loss = 949691.2686, val recon loss = 93771.2087 & val kl loss = 11979.1773
# epoch = 435; total train loss = 4548427.4194, train recon loss = 448829.0736, train kl loss = 60136.6815; total val loss = 950477.3750, val recon loss = 93840.8761 & val kl loss = 12068.6136
# epoch = 436; total train loss = 4548312.7905, train recon loss = 448821.9567, train kl loss = 60093.2212; total val loss = 950052.0532, val recon loss = 93782.8616 & val kl loss = 12223.4373
# epoch = 437; total train loss = 4548623.0801, train recon loss = 448853.2516, train kl loss = 60090.5640; total val loss = 951036.3755, val recon loss = 93888.0542 & val kl loss = 12155.8319
# epoch = 438; total train loss = 4548206.9717, train recon loss = 448808.3320, train kl loss = 60123.6484; total val loss = 950489.4463, val recon loss = 93831.2471 & val kl loss = 12176.9748
# epoch = 439; total train loss = 4547823.3115, train recon loss = 448766.9618, train kl loss = 60153.6911; total val loss = 949766.9087, val recon loss = 93783.2727 & val kl loss = 11934.1842
# epoch = 440; total train loss = 4548267.4287, train recon loss = 448813.2552, train kl loss = 60134.8692; total val loss = 949628.6797, val recon loss = 93758.4806 & val kl loss = 12043.8768
# epoch = 441; total train loss = 4547998.0596, train recon loss = 448786.5344, train kl loss = 60132.7213; total val loss = 950211.3877, val recon loss = 93812.1623 & val kl loss = 12089.7655
# epoch = 442; total train loss = 4548292.4248, train recon loss = 448817.5652, train kl loss = 60116.7691; total val loss = 949443.6709, val recon loss = 93733.3080 & val kl loss = 12110.5910
# epoch = 443; total train loss = 4547805.5610, train recon loss = 448767.3193, train kl loss = 60132.3739; total val loss = 950790.1343, val recon loss = 93862.1183 & val kl loss = 12168.9556
# epoch = 444; total train loss = 4547835.8511, train recon loss = 448768.4572, train kl loss = 60151.2729; total val loss = 951636.0820, val recon loss = 93937.2767 & val kl loss = 12263.3143
# epoch = 445; total train loss = 4548180.4609, train recon loss = 448803.6149, train kl loss = 60144.3141; total val loss = 950712.8540, val recon loss = 93877.8265 & val kl loss = 11934.5886
# epoch = 446; total train loss = 4547565.5996, train recon loss = 448738.2602, train kl loss = 60183.0006; total val loss = 949948.3418, val recon loss = 93787.9382 & val kl loss = 12068.9561
# epoch = 447; total train loss = 4547630.0288, train recon loss = 448742.7944, train kl loss = 60202.0734; total val loss = 949500.5903, val recon loss = 93738.7400 & val kl loss = 12113.1967
# epoch = 448; total train loss = 4547345.4375, train recon loss = 448721.6624, train kl loss = 60128.8145; total val loss = 950417.9072, val recon loss = 93832.9177 & val kl loss = 12088.7279
# epoch = 449; total train loss = 4547608.3911, train recon loss = 448741.6646, train kl loss = 60191.7356; total val loss = 949663.3271, val recon loss = 93775.9691 & val kl loss = 11903.6316
# epoch = 450; total train loss = 4547877.1240, train recon loss = 448772.5053, train kl loss = 60152.0694; total val loss = 949841.6729, val recon loss = 93750.7382 & val kl loss = 12334.2911
# epoch = 451; total train loss = 4547448.4785, train recon loss = 448727.2960, train kl loss = 60175.5237; total val loss = 950539.4141, val recon loss = 93866.8258 & val kl loss = 11871.1551
# epoch = 452; total train loss = 4547559.3574, train recon loss = 448738.7205, train kl loss = 60172.1656; total val loss = 949811.0522, val recon loss = 93762.7570 & val kl loss = 12183.4806
# epoch = 453; total train loss = 4547693.5298, train recon loss = 448748.1070, train kl loss = 60212.4612; total val loss = 951013.1523, val recon loss = 93885.5153 & val kl loss = 12158.0005
# epoch = 454; total train loss = 4547202.4575, train recon loss = 448698.7840, train kl loss = 60214.6203; total val loss = 950186.4541, val recon loss = 93810.6047 & val kl loss = 12080.4070
# epoch = 455; total train loss = 4547097.9214, train recon loss = 448687.6237, train kl loss = 60221.6784; total val loss = 950738.2378, val recon loss = 93851.4395 & val kl loss = 12223.8423
# epoch = 456; total train loss = 4547497.0308, train recon loss = 448732.0541, train kl loss = 60176.4923; total val loss = 950035.1235, val recon loss = 93775.4870 & val kl loss = 12280.2556
# epoch = 457; total train loss = 4547480.6294, train recon loss = 448723.4820, train kl loss = 60245.8095; total val loss = 949707.5024, val recon loss = 93753.2246 & val kl loss = 12175.2586
# epoch = 458; total train loss = 4547399.6978, train recon loss = 448714.7232, train kl loss = 60252.4638; total val loss = 949404.0781, val recon loss = 93736.4561 & val kl loss = 12039.5178
# epoch = 459; total train loss = 4547522.2749, train recon loss = 448730.3845, train kl loss = 60218.4246; total val loss = 950505.8936, val recon loss = 93838.8174 & val kl loss = 12117.7241
# epoch = 460; total train loss = 4546889.2451, train recon loss = 448663.4536, train kl loss = 60254.7129; total val loss = 950208.8564, val recon loss = 93798.0483 & val kl loss = 12228.3790
# epoch = 461; total train loss = 4547036.8374, train recon loss = 448679.9669, train kl loss = 60237.1633; total val loss = 949739.7681, val recon loss = 93764.0312 & val kl loss = 12099.4546
# epoch = 462; total train loss = 4547238.9868, train recon loss = 448700.8986, train kl loss = 60230.0008; total val loss = 948845.6060, val recon loss = 93678.0079 & val kl loss = 12065.5316
# epoch = 463; total train loss = 4546934.8574, train recon loss = 448668.9147, train kl loss = 60245.7132; total val loss = 949797.9097, val recon loss = 93772.9338 & val kl loss = 12068.5740
# epoch = 464; total train loss = 4547099.9121, train recon loss = 448685.9090, train kl loss = 60240.8227; total val loss = 950605.8950, val recon loss = 93833.7864 & val kl loss = 12268.0339
# epoch = 465; total train loss = 4547143.9858, train recon loss = 448684.6933, train kl loss = 60297.0463; total val loss = 951017.5078, val recon loss = 93879.3992 & val kl loss = 12223.5172
# epoch = 466; total train loss = 4547160.1919, train recon loss = 448683.5508, train kl loss = 60324.6829; total val loss = 951421.7300, val recon loss = 93931.5237 & val kl loss = 12106.4927
# epoch = 467; total train loss = 4546799.6978, train recon loss = 448651.1091, train kl loss = 60288.6083; total val loss = 950085.5811, val recon loss = 93782.0482 & val kl loss = 12265.0987
# epoch = 468; total train loss = 4546802.1777, train recon loss = 448649.3923, train kl loss = 60308.2555; total val loss = 950238.4780, val recon loss = 93807.3322 & val kl loss = 12165.1585
# epoch = 469; total train loss = 4546643.1440, train recon loss = 448633.0963, train kl loss = 60312.1829; total val loss = 952270.2407, val recon loss = 94014.9771 & val kl loss = 12120.4669
# epoch = 470; total train loss = 4546621.9468, train recon loss = 448633.8742, train kl loss = 60283.1971; total val loss = 949737.4023, val recon loss = 93773.9687 & val kl loss = 11997.7150
# epoch = 471; total train loss = 4546752.3599, train recon loss = 448645.3417, train kl loss = 60298.9438; total val loss = 949935.5645, val recon loss = 93779.6601 & val kl loss = 12138.9642
# epoch = 472; total train loss = 4546674.7744, train recon loss = 448639.8903, train kl loss = 60275.8757; total val loss = 950869.0352, val recon loss = 93896.7084 & val kl loss = 11901.9543
# epoch = 473; total train loss = 4546603.0132, train recon loss = 448633.0894, train kl loss = 60272.1154; total val loss = 949560.2461, val recon loss = 93748.9151 & val kl loss = 12071.0956
# epoch = 474; total train loss = 4546294.6055, train recon loss = 448596.3555, train kl loss = 60331.0477; total val loss = 949377.8364, val recon loss = 93753.8962 & val kl loss = 11838.8765
# epoch = 475; total train loss = 4546633.6528, train recon loss = 448636.6459, train kl loss = 60267.1995; total val loss = 951014.3828, val recon loss = 93889.4474 & val kl loss = 12119.9077
# epoch = 476; total train loss = 4546146.6538, train recon loss = 448582.0930, train kl loss = 60325.7227; total val loss = 949728.0557, val recon loss = 93776.2363 & val kl loss = 11965.6927
# epoch = 477; total train loss = 4546557.0581, train recon loss = 448620.2147, train kl loss = 60354.9079; total val loss = 951888.6050, val recon loss = 93974.6342 & val kl loss = 12142.2643
# epoch = 478; total train loss = 4546432.7988, train recon loss = 448613.6357, train kl loss = 60296.4365; total val loss = 950006.8140, val recon loss = 93782.9033 & val kl loss = 12177.7829
# epoch = 479; total train loss = 4546151.0977, train recon loss = 448586.8012, train kl loss = 60283.0864; total val loss = 950262.6714, val recon loss = 93820.1960 & val kl loss = 12060.7129
# epoch = 480; total train loss = 4546342.6040, train recon loss = 448605.9338, train kl loss = 60283.2613; total val loss = 950057.5229, val recon loss = 93783.6883 & val kl loss = 12220.6364
# epoch = 481; total train loss = 4546298.2480, train recon loss = 448597.0057, train kl loss = 60328.1784; total val loss = 951201.8838, val recon loss = 93909.7618 & val kl loss = 12104.2672
# epoch = 482; total train loss = 4546229.8999, train recon loss = 448588.9532, train kl loss = 60340.3754; total val loss = 951063.3389, val recon loss = 93892.1892 & val kl loss = 12141.4463
# epoch = 483; total train loss = 4546100.5063, train recon loss = 448576.8541, train kl loss = 60331.9687; total val loss = 949941.3330, val recon loss = 93796.8168 & val kl loss = 11973.1626
# epoch = 484; total train loss = 4546428.6963, train recon loss = 448610.7631, train kl loss = 60321.0743; total val loss = 950913.3848, val recon loss = 93879.3784 & val kl loss = 12119.6022
# epoch = 485; total train loss = 4546022.1543, train recon loss = 448568.0482, train kl loss = 60341.6645; total val loss = 949772.7720, val recon loss = 93767.4824 & val kl loss = 12097.9497
# epoch = 486; total train loss = 4546068.0537, train recon loss = 448570.3782, train kl loss = 60364.2630; total val loss = 950078.6011, val recon loss = 93796.7584 & val kl loss = 12111.0190
# epoch = 487; total train loss = 4546313.4878, train recon loss = 448595.8359, train kl loss = 60355.1374; total val loss = 949234.2827, val recon loss = 93716.8810 & val kl loss = 12065.4714
# epoch = 488; total train loss = 4545872.9507, train recon loss = 448550.0083, train kl loss = 60372.8571; total val loss = 949996.5029, val recon loss = 93780.8477 & val kl loss = 12188.0272
# epoch = 489; total train loss = 4545957.0747, train recon loss = 448558.0053, train kl loss = 60377.0178; total val loss = 949292.4775, val recon loss = 93733.0518 & val kl loss = 11961.9560
# epoch = 490; total train loss = 4546242.5503, train recon loss = 448586.7983, train kl loss = 60374.5625; total val loss = 950689.1245, val recon loss = 93838.5943 & val kl loss = 12303.1825
# epoch = 491; total train loss = 4545958.8970, train recon loss = 448561.4039, train kl loss = 60344.8735; total val loss = 951003.8120, val recon loss = 93882.6080 & val kl loss = 12177.7290
# epoch = 492; total train loss = 4545585.0654, train recon loss = 448522.1271, train kl loss = 60363.7901; total val loss = 950968.2705, val recon loss = 93889.3282 & val kl loss = 12074.9889
# epoch = 493; total train loss = 4545832.5254, train recon loss = 448545.9722, train kl loss = 60372.8012; total val loss = 949371.9185, val recon loss = 93728.5090 & val kl loss = 12086.8283
# epoch = 494; total train loss = 4545693.6953, train recon loss = 448535.4326, train kl loss = 60339.3742; total val loss = 951361.3608, val recon loss = 93917.6011 & val kl loss = 12185.3477
# epoch = 495; total train loss = 4545521.8154, train recon loss = 448512.9683, train kl loss = 60392.1232; total val loss = 950490.7583, val recon loss = 93819.8155 & val kl loss = 12292.6007
# epoch = 496; total train loss = 4545673.5747, train recon loss = 448525.7983, train kl loss = 60415.5887; total val loss = 950806.1060, val recon loss = 93860.6584 & val kl loss = 12199.5234
# epoch = 497; total train loss = 4545712.5317, train recon loss = 448532.4695, train kl loss = 60387.8332; total val loss = 949650.9282, val recon loss = 93746.0415 & val kl loss = 12190.5146
# epoch = 498; total train loss = 4545580.8623, train recon loss = 448514.6552, train kl loss = 60434.3055; total val loss = 950691.2388, val recon loss = 93860.4858 & val kl loss = 12086.3801
# epoch = 499; total train loss = 4545557.7949, train recon loss = 448516.2172, train kl loss = 60395.6231; total val loss = 950324.9062, val recon loss = 93823.0684 & val kl loss = 12094.2210
# epoch = 500; total train loss = 4545666.4194, train recon loss = 448527.2883, train kl loss = 60393.5391; total val loss = 949544.8623, val recon loss = 93740.3172 & val kl loss = 12141.6879

# %%
model.save('vgg_based_250')
# Out:
# INFO:tensorflow:Assets written to: vgg_based_500/assets

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_data = X_test[:2000]
y_data = y_test[:2000]

# %%
# mu_np = model.mu.numpy()
# sigm_np = model.log_var.numpy()

# mu_np = np.mean(mu_np)
# sigm_np1 = np.mean(np.exp(sigm_np))
# sigm_np2 = np.exp(np.mean(sigm_np))

# %matplotlib inline
# z_ex = np.random.normal(mu_np, sigm_np1, 100)
# X_hat = tf.keras.activations.sigmoid(model.decoder(z_ex.reshape(1, 100)))
# plt.imshow(X_hat[0], cmap='gray')

# %%
# %matplotlib inline
j = 10
lat = model.encoder(x_data[j].reshape(1,32,32,3))
plt.imshow(x_data[j])

# %%
mu = model.mu(lat)
var = model.log_var(lat)
z = Sampling()(mu, var)
x_hat = tf.keras.activations.sigmoid(model.decoder(z))
plt.imshow(x_hat[0])

# %%
data_recon, mu, log_var, z = model(x_data)

# %%
# %matplotlib inline
i=50
plt.imshow(data_recon[i])

# %%
plt.imshow(x_data[i])

# %%
# z_gen = np.random.normal(0, 1, 100)
# z_gen.shape
mu = tf.random.normal([100], 0, 1, tf.float32)
sigma = tf.random.normal([100], 0, 1, tf.float32)
z_gen = model.reparameterize(mu, sigma)
X_hat = tf.keras.activations.sigmoid(model.decoder(z_gen.numpy().reshape(1, 100)))
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(2)
plt.imshow(X_hat[0])

# %%
# 0 airplane 1 car 2 bird 3 cat 4 deer 5 dog 6 frog 7 horse 8 ship 9 truck
