# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
  except RuntimeError as e:
    print(e)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Input, Flatten,\
Conv2DTranspose, BatchNormalization, LeakyReLU, Reshape, MaxPooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.datasets import cifar10
import tensorflow.keras.backend as K
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

# %%
# input image dimensions
img_rows, img_cols = 32, 32
# Load CIFAR-10 dataset-
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
if tf.keras.backend.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 3)
    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

# %%
# Specify hyper-parameters-
batch_size = 64
num_classes = 10
num_epochs = 100

# %%
# Convert datasets to floating point types-
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the training and testing datasets-
X_train /= 255.0
X_test /= 255.0

print("\nDimensions of training and testing sets are:")
print(f"X_train.shape: {X_train.shape} & X_test.shape: {X_test.shape}")


# Create TF datasets-
train_dataset = tf.data.Dataset.from_tensor_slices(X_train).shuffle(50000).batch(batch_size = batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices(X_test).shuffle(10000).batch(batch_size = batch_size)
# Out:
# Dimensions of training and testing sets are:
# X_train.shape: (50000, 32, 32, 3) & X_test.shape: (10000, 32, 32, 3)

# %%
class ConvBlock(Model):
    def __init__(
        self, num_filters,
        kernel_size, stride_length,
        pooling_size, pooling_stride,
        padding_type = 'same'
    ):
        super(ConvBlock, self).__init__()
        
        self.conv1 = Conv2D(
            filters = num_filters, kernel_size = kernel_size,
            strides = stride_length, padding = padding_type,
            activation = None, use_bias = False,
        )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv2 = Conv2D(
            filters = num_filters, kernel_size = kernel_size,
            strides = stride_length, padding = padding_type,
            activation = None, use_bias = False
        )
        self.bn2 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.pool = MaxPooling2D(
            pool_size = pooling_size,
            strides = pooling_stride
        )
        
    
    def call(self, x):
        x = tf.keras.activations.relu(self.bn(self.conv1(x)))
        x = tf.keras.activations.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        
        return x

# %%
class Conv6_Encoder(Model):
    def __init__(self, latent_dim = 10):
        super(Conv6_Encoder, self).__init__()

        self.latent_dim = latent_dim
        
        self.conv_block1 = ConvBlock(
            num_filters = 64, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'valid'
            )

        self.conv_block2 = ConvBlock(
            num_filters = 128, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'valid'
            )
        
        self.conv_block3 = ConvBlock(
            num_filters = 256, kernel_size = 3,
            stride_length = 1, pooling_size = 2,
            pooling_stride = 2, padding_type = 'same'
            )

        self.flatten = Flatten()
        
        self.output_layer = Dense(
            units = self.latent_dim, activation = None
            )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
    
    def call(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.flatten(x)
        x = tf.keras.activations.relu(self.bn(self.output_layer(x)))
        return x
    
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (32, 32, 3))
        return Model(inputs = [x], outputs = self.call(x))
    
    def shape_computation(self, x):
        print(f"Input shape: {x.shape}")
        x = self.conv_block1(x)
        print(f"conv_block1.shape: {x.shape}")
        x = self.conv_block2(x)
        print(f"conv_block2.shape: {x.shape}")
        x = self.conv_block3(x)
        print(f"conv_block3.shape: {x.shape}")
        x = self.flatten(x)
        print(f"flattened shape: {x.shape}")
        x = tf.keras.activations.relu(self.bn(self.output_layer(x)))
        print(f"Encoder output shape: {x.shape}")
        '''
        Input shape: (64, 32, 32, 3)
        conv_block1.shape: (64, 14, 14, 64)
        conv_block2.shape: (64, 5, 5, 128)
        conv_block3.shape: (64, 2, 2, 256)
        flattened shape: (64, 1024)
        Encoder output shape: (64, 100)
        '''
        
        return None

# %%
class Conv6_Decoder(Model):
    def __init__(self, latent_dim = 10):
        super(Conv6_Decoder, self).__init__()

        self.latent_dim = latent_dim
        
        # self.inp_layer = InputLayer(input_shape = self.latent_dim)
        
        self.dense0 = Dense(
            units = self.latent_dim, activation = None
            )
        self.bn0 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.dense = Dense(
            units = 1024, activation = None
        )
        self.bn = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.dense2 = Dense(
            units = 4 * 4 * 256, activation = None
        )
        self.bn2 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.reshape = Reshape((4, 4, 256))
        
        self.conv_transpose_layer1 = Conv2DTranspose(
            filters = 256, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn3 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
       
        self.conv_transpose_layer2 = Conv2DTranspose(
            filters = 256, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn4 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv_transpose_layer3 =  Conv2DTranspose(
            filters = 128, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn5 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.conv_transpose_layer4 = Conv2DTranspose(
            filters = 128, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn6 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )

        self.conv_transpose_layer5 = Conv2DTranspose(
            filters = 64, kernel_size = 3,
            strides = 2, padding = 'same',
            activation = None
            )
        self.bn7 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
       
        self.conv_transpose_layer6 = Conv2DTranspose(
            filters = 64, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
        self.bn8 = BatchNormalization(
            axis = -1, momentum = 0.99,
            epsilon = 0.001
            )
        
        self.final_conv_layer = Conv2DTranspose(
            filters = 3, kernel_size = 3,
            strides = 1, padding = 'same',
            activation = None
            )
        
    
    def call(self, X):
        # X = self.inp_layer(X)
        X = tf.keras.activations.relu(self.bn0(self.dense0(X)))
        X = tf.keras.activations.relu(self.bn(self.dense(X)))
        X = tf.keras.activations.relu(self.bn2(self.dense2(X)))
        X = self.reshape(X)
        X = tf.keras.activations.relu(self.bn3(self.conv_transpose_layer1(X)))
        X = tf.keras.activations.relu(self.bn4(self.conv_transpose_layer2(X)))
        X = tf.keras.activations.relu(self.bn5(self.conv_transpose_layer3(X)))
        X = tf.keras.activations.relu(self.bn6(self.conv_transpose_layer4(X)))
        X = tf.keras.activations.relu(self.bn7(self.conv_transpose_layer5(X)))
        X = tf.keras.activations.relu(self.bn8(self.conv_transpose_layer6(X)))
        # X = tf.keras.activations.sigmoid(self.final_conv_layer(X))
        X = self.final_conv_layer(X)

        return X
        
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (100))
        return Model(inputs = [x], outputs = self.call(x))
    
    def shape_computation(self, x):
        print(f"Input shape: {x.shape}")
        x = tf.nn.relu(self.bn0(self.dense0(x)))
        print(f"first dense layer shape: {x.shape}")
        x = tf.nn.relu(self.bn(self.dense(x)))
        print(f"second dense layer shape: {x.shape}")
        x = tf.nn.relu(self.bn2(self.dense2(x)))
        print(f"third dense layer shape: {x.shape}")
        x = self.reshape(x)
        print(f"reshape: {x.shape}")
        x = tf.nn.relu(self.bn3(self.conv_transpose_layer1(x)))
        print(f"conv transpose layer1 shape: {x.shape}")
        x = tf.nn.relu(self.bn4(self.conv_transpose_layer2(x)))
        print(f"conv transpose layer2 shape: {x.shape}")
        x = tf.nn.relu(self.bn5(self.conv_transpose_layer3(x)))
        print(f"conv transpose layer3 shape: {x.shape}")
        x = tf.nn.relu(self.bn6(self.conv_transpose_layer4(x)))
        print(f"conv transpose layer4 shape: {x.shape}")
        x = tf.nn.relu(self.bn7(self.conv_transpose_layer5(x)))
        print(f"conv transpose layer5 shape: {x.shape}")
        x = tf.nn.relu(self.bn8(self.conv_transpose_layer6(x)))
        print(f"conv transpose layer6 shape: {x.shape}")
        x = self.final_conv_layer(x)
        print(f"Decoder output shape: {x.shape}")
        
        '''
        Input shape: (64, 100)
        first dense layer shape: (64, 100)
        second dense layer shape: (64, 1024)
        third dense layer shape: (64, 4096)
        reshape: (64, 4, 4, 256)
        conv transpose layer1 shape: (64, 8, 8, 256)
        conv transpose layer2 shape: (64, 8, 8, 256)
        conv transpose layer3 shape: (64, 16, 16, 128)
        conv transpose layer4 shape: (64, 16, 16, 128)
        conv transpose layer5 shape: (64, 32, 32, 64)
        conv transpose layer6 shape: (64, 32, 32, 64)
        Decoder output shape: (64, 32, 32, 3)
        '''
        
        return None

# %%
class Sampling(tf.keras.layers.Layer):
    """
    Create a sampling layer.
    Uses (mu, log_var) to sample latent vector 'z'.
    """
    def call(self, mu, log_var):
    # def call(self, inputs):
        # z_mean, z_log_var = inputs

        # Get batch size-
        batch = tf.shape(mu)[0]

        # Get latent space dimensionality-
        dim = tf.shape(mu)[1]

        # Add stochasticity by sampling from a multivariate standard 
        # Gaussian distribution-
        epsilon = tf.keras.backend.random_normal(
            shape = (batch, dim), mean = 0.0,
            stddev = 1.0
        )

        return mu + (tf.exp(0.5 * log_var) * epsilon)

# %%
class VAE(Model):
    def __init__(self, latent_space = 100):
        super(VAE, self).__init__()
        
        self.latent_space = latent_space
        
        self.encoder = Conv6_Encoder(latent_dim = self.latent_space)
        self.decoder = Conv6_Decoder(latent_dim = self.latent_space)
        
        # Define fully-connected layers for computing mean & log variance-
        self.mu = Dense(units = self.latent_space, activation = None)
        self.log_var = Dense(units = self.latent_space, activation = None)


    def reparameterize(self, mu, logvar):
        # Sample from a multivariate Gaussian distribution.
        # Adds stochasticity or variation-
        eps = tf.random.normal(
            shape = mu.shape, mean = 0.0,
            stddev = 1.0
        )
        return (eps * tf.exp(logvar * 0.5) + mu)
        
    
    def call(self, x):
        x = self.encoder(x)
        # print(f"x.shape: {x.shape}")
        # x.shape: (batch_size, 100)
        
        mu = self.mu(x)
        log_var = self.log_var(x)
        # z = self.reparameterize(mu, log_var)
        # z = Sampling()([mu, log_var])
        z = Sampling()(mu, log_var)
        '''
        print(f"mu.shape: {mu.shape}, log_var.shape: {log_var.shape}"
              f" & z.shape: {z.shape}")
        # mu.shape: (batch_size, 100), log_var.shape: (batch_size, 100) & z.shape: (batch_size, 100)
        '''
        
        x = tf.keras.activations.sigmoid(self.decoder(z))
        return x, mu, log_var, z
    
    
    def model(self):
        '''
        Overrides 'model()' call.
        Output shape is not well-defined when using sub-classing. As a
        workaround, this method is implemeted.
        '''
        x = Input(shape = (32, 32, 3))
        return Model(inputs = [x], outputs = self.call(x))

# %%
# Initialize VAE model-
model = VAE(latent_space = 100)

# %%
# Get model summary-
model.model().summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv6__encoder_3 (Conv6_Encode  (None, 100)         1250996     ['input_7[0][0]']
#  r)
#
#  dense_22 (Dense)               (None, 100)          10100       ['conv6__encoder_3[0][0]']
#
#  dense_23 (Dense)               (None, 100)          10100       ['conv6__encoder_3[0][0]']
#
#  sampling_7 (Sampling)          (None, 100)          0           ['dense_22[0][0]',
#                                                                   'dense_23[0][0]']
#
#  conv6__decoder_3 (Conv6_Decode  (None, 32, 32, 3)   6071623     ['sampling_7[0][0]']
#  r)
#
#  tf.math.sigmoid_4 (TFOpLambda)  (None, 32, 32, 3)   0           ['conv6__decoder_3[0][0]']
#
# ==================================================================================================
# Total params: 7,342,819
# Trainable params: 7,328,595
# Non-trainable params: 14,224
# __________________________________________________________________________________________________

# %%
# Define an optimizer-
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4)

# %%
def compute_loss(data, reconstruction, mu, log_var, alpha = 1):
    
    # Reconstruction loss-
    # recon_loss = tf.keras.losses.mean_squared_error(K.flatten(data), K.flatten(reconstruction))

    recon_loss = tf.reduce_mean(
        tf.reduce_sum(
            # tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
            tf.keras.losses.mean_squared_error(data, reconstruction),
            axis = (1, 2)
            )
        )
    
    # KL-divergence loss-    
    kl_loss = -0.5 * (1 + log_var - tf.square(mu) - tf.exp(log_var))
    kl_loss = tf.reduce_mean(
        tf.reduce_sum(
            kl_loss,
            axis = 1
        )
    )

    total_loss = (recon_loss * alpha) + kl_loss
    
    return total_loss, recon_loss, kl_loss

# %%
@tf.function
def train_one_step(model, optimizer, data, alpha):
    # Function to perform one step/iteration of training

    with tf.GradientTape() as tape:
        # Make predictions using defined model-
        data_recon, mu, log_var, z = model(data)

        # Compute loss-
        total_loss, recon_loss, kl_loss = compute_loss(
            data = data, reconstruction = data_recon,
            mu = mu, log_var = log_var,
            alpha = alpha
        )
    
    # Compute gradients wrt defined loss and weights and biases-
    grads = tape.gradient(total_loss, model.trainable_variables)
    
    # type(grads)
    # list
    
    # Apply computed gradients to model's weights and biases-
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return total_loss, recon_loss, kl_loss


@tf.function
def test_step(model, optimizer, data, alpha):
    '''
    Function to test model performance
    on testing dataset
    '''
    # Make predictions using defined model-
    data_recon, mu, log_var, z = model(data)
    
    # Compute loss-
    total_loss, recon_loss, kl_loss = compute_loss(
        data = data, reconstruction = data_recon,
        mu = mu, log_var = log_var,
        alpha = alpha
    )
    
    return total_loss, recon_loss, kl_loss

# %%
# Specify hyper-parameter for reconstruction loss vs. kl-divergence-
alpha = 10

# Python3 dict to contain training metrics-
training_metrics = {}
val_metrics = {}

# %%
for epoch in range(1, num_epochs + 1):
    """
    # Manual early stopping implementation-
    if loc_patience >= patience:
        print("\n'EarlyStopping' called!\n")
        break
    """

    # Epoch train & validation losses-
    train_loss = 0.0
    train_r_loss = 0.0
    train_kl_l = 0.0
    val_loss = 0.0
    val_r_loss = 0.0
    val_kl_l = 0.0
    
    for data in train_dataset:
        train_total_loss, train_recon_loss, train_kl_loss = train_one_step(
            model = model, optimizer = optimizer,
            data = data, alpha = alpha
        )
        
        train_loss += train_total_loss.numpy()
        train_r_loss += train_recon_loss.numpy()
        train_kl_l += train_kl_loss.numpy()
    
    for test_data in test_dataset:
        test_total_loss, test_recon_loss, test_kl_loss = test_step(
            model = model, optimizer = optimizer,
            data = test_data, alpha = alpha)
        
        val_loss += test_total_loss.numpy()
        val_r_loss += test_recon_loss.numpy()
        val_kl_l += test_kl_loss.numpy()
    
    # vae_train_loss.append(train_loss)
    # vae_val_loss.append(val_loss)

    training_metrics[epoch] = {
        'total_loss': train_loss, 'recon_loss': train_r_loss,
        'kl_loss': train_kl_l
        }
    
    val_metrics[epoch] = {
        'total_loss': val_loss, 'recon_loss': val_r_loss,
        'kl_loss': val_kl_l
    }

    print(f"epoch = {epoch}; total train loss = {train_loss:.4f},"
    f" train recon loss = {train_r_loss:.4f}, train kl loss = {train_kl_l:.4f};"
    f" total val loss = {val_loss:.4f}, val recon loss = {val_r_loss:.4f} &"
    f" val kl loss = {val_kl_l:.4f}"
    )
# Out:
# epoch = 1; total train loss = 266476.3743, train recon loss = 24457.0976, train kl loss = 21905.3986; total val loss = 50833.4209, val recon loss = 4595.4000 & val kl loss = 4879.4210
# epoch = 2; total train loss = 243435.3065, train recon loss = 21764.7429, train kl loss = 25787.8771; total val loss = 47579.2012, val recon loss = 4230.7438 & val kl loss = 5271.7629
# epoch = 3; total train loss = 229463.7964, train recon loss = 20251.5533, train kl loss = 26948.2642; total val loss = 43599.5275, val recon loss = 3788.0909 & val kl loss = 5718.6184
# epoch = 4; total train loss = 212177.3595, train recon loss = 18326.9644, train kl loss = 28907.7159; total val loss = 42605.3393, val recon loss = 3681.0596 & val kl loss = 5794.7435
# epoch = 5; total train loss = 205100.2634, train recon loss = 17601.1361, train kl loss = 29088.9030; total val loss = 40416.6838, val recon loss = 3458.6314 & val kl loss = 5830.3702
# epoch = 6; total train loss = 199474.7827, train recon loss = 17038.8350, train kl loss = 29086.4320; total val loss = 39773.2392, val recon loss = 3387.1680 & val kl loss = 5901.5590
# epoch = 7; total train loss = 194745.9317, train recon loss = 16550.7166, train kl loss = 29238.7654; total val loss = 38802.9150, val recon loss = 3295.4427 & val kl loss = 5848.4885
# epoch = 8; total train loss = 190094.8008, train recon loss = 16086.8760, train kl loss = 29226.0407; total val loss = 37793.7842, val recon loss = 3193.6329 & val kl loss = 5857.4552
# epoch = 9; total train loss = 185762.0624, train recon loss = 15626.7650, train kl loss = 29494.4124; total val loss = 37480.0419, val recon loss = 3150.4100 & val kl loss = 5975.9416
# epoch = 10; total train loss = 182302.5879, train recon loss = 15280.8559, train kl loss = 29494.0291; total val loss = 36248.3582, val recon loss = 3035.7799 & val kl loss = 5890.5588
# epoch = 11; total train loss = 178313.2285, train recon loss = 14883.8574, train kl loss = 29474.6546; total val loss = 35576.5366, val recon loss = 2959.4583 & val kl loss = 5981.9537
# epoch = 12; total train loss = 174757.7395, train recon loss = 14508.2615, train kl loss = 29675.1251; total val loss = 35020.8276, val recon loss = 2904.2852 & val kl loss = 5977.9753
# epoch = 13; total train loss = 171366.1343, train recon loss = 14156.8363, train kl loss = 29797.7711; total val loss = 34539.0157, val recon loss = 2849.3178 & val kl loss = 6045.8375
# epoch = 14; total train loss = 168761.2037, train recon loss = 13903.5707, train kl loss = 29725.4972; total val loss = 33823.7639, val recon loss = 2777.5518 & val kl loss = 6048.2462
# epoch = 15; total train loss = 166395.0402, train recon loss = 13684.3981, train kl loss = 29551.0589; total val loss = 33712.6353, val recon loss = 2774.5763 & val kl loss = 5966.8719
# epoch = 16; total train loss = 164236.9114, train recon loss = 13486.0415, train kl loss = 29376.4960; total val loss = 33217.5212, val recon loss = 2722.9638 & val kl loss = 5987.8829
# epoch = 17; total train loss = 162460.0889, train recon loss = 13323.4705, train kl loss = 29225.3838; total val loss = 32699.1548, val recon loss = 2677.9958 & val kl loss = 5919.1971
# epoch = 18; total train loss = 160740.4440, train recon loss = 13153.6309, train kl loss = 29204.1352; total val loss = 32608.5233, val recon loss = 2666.5260 & val kl loss = 5943.2637
# epoch = 19; total train loss = 158876.6371, train recon loss = 12959.9878, train kl loss = 29276.7595; total val loss = 32257.7411, val recon loss = 2636.5804 & val kl loss = 5891.9371
# epoch = 20; total train loss = 157469.8009, train recon loss = 12808.8067, train kl loss = 29381.7341; total val loss = 31895.6749, val recon loss = 2594.2129 & val kl loss = 5953.5457
# epoch = 21; total train loss = 155979.5925, train recon loss = 12662.7942, train kl loss = 29351.6508; total val loss = 31962.7191, val recon loss = 2627.8110 & val kl loss = 5684.6093
# epoch = 22; total train loss = 154646.5947, train recon loss = 12531.8607, train kl loss = 29327.9880; total val loss = 31683.5392, val recon loss = 2573.2255 & val kl loss = 5951.2842
# epoch = 23; total train loss = 153438.9222, train recon loss = 12406.5756, train kl loss = 29373.1666; total val loss = 31118.8182, val recon loss = 2526.1850 & val kl loss = 5856.9678
# epoch = 24; total train loss = 152328.3838, train recon loss = 12295.5921, train kl loss = 29372.4625; total val loss = 30968.6766, val recon loss = 2506.7727 & val kl loss = 5900.9495
# epoch = 25; total train loss = 151051.8279, train recon loss = 12155.9481, train kl loss = 29492.3470; total val loss = 30765.9774, val recon loss = 2474.3555 & val kl loss = 6022.4226
# epoch = 26; total train loss = 150058.9221, train recon loss = 12043.0823, train kl loss = 29628.0993; total val loss = 30550.9627, val recon loss = 2460.3708 & val kl loss = 5947.2545
# epoch = 27; total train loss = 148801.9003, train recon loss = 11905.5371, train kl loss = 29746.5296; total val loss = 30499.9052, val recon loss = 2444.5514 & val kl loss = 6054.3913
# epoch = 28; total train loss = 147720.2392, train recon loss = 11788.0638, train kl loss = 29839.6018; total val loss = 30529.2039, val recon loss = 2456.6968 & val kl loss = 5962.2354
# epoch = 29; total train loss = 146964.7430, train recon loss = 11703.5491, train kl loss = 29929.2521; total val loss = 30121.8516, val recon loss = 2399.1150 & val kl loss = 6130.7016
# epoch = 30; total train loss = 145908.0511, train recon loss = 11591.0674, train kl loss = 29997.3767; total val loss = 30081.1049, val recon loss = 2411.6389 & val kl loss = 5964.7154
# epoch = 31; total train loss = 145085.2851, train recon loss = 11501.7864, train kl loss = 30067.4211; total val loss = 30082.9792, val recon loss = 2393.1211 & val kl loss = 6151.7687
# epoch = 32; total train loss = 144359.6985, train recon loss = 11422.6299, train kl loss = 30133.3998; total val loss = 30011.3224, val recon loss = 2409.4977 & val kl loss = 5916.3459
# epoch = 33; total train loss = 143486.8789, train recon loss = 11328.0181, train kl loss = 30206.6983; total val loss = 29915.8606, val recon loss = 2391.3170 & val kl loss = 6002.6906
# epoch = 34; total train loss = 142930.0046, train recon loss = 11262.1927, train kl loss = 30308.0782; total val loss = 29639.4974, val recon loss = 2352.1280 & val kl loss = 6118.2176
# epoch = 35; total train loss = 142171.3651, train recon loss = 11177.7704, train kl loss = 30393.6605; total val loss = 29663.3350, val recon loss = 2336.6522 & val kl loss = 6296.8130
# epoch = 36; total train loss = 141487.5725, train recon loss = 11102.2169, train kl loss = 30465.4033; total val loss = 29651.0177, val recon loss = 2352.2666 & val kl loss = 6128.3519
# epoch = 37; total train loss = 140847.4453, train recon loss = 11030.2245, train kl loss = 30545.1998; total val loss = 29608.7826, val recon loss = 2361.1133 & val kl loss = 5997.6495
# epoch = 38; total train loss = 140199.5817, train recon loss = 10959.0101, train kl loss = 30609.4800; total val loss = 29516.0400, val recon loss = 2333.9840 & val kl loss = 6176.1996
# epoch = 39; total train loss = 139652.2830, train recon loss = 10894.1045, train kl loss = 30711.2387; total val loss = 29428.7794, val recon loss = 2334.6475 & val kl loss = 6082.3045
# epoch = 40; total train loss = 138961.0387, train recon loss = 10818.7691, train kl loss = 30773.3475; total val loss = 29472.4049, val recon loss = 2346.3089 & val kl loss = 6009.3157
# epoch = 41; total train loss = 138414.2844, train recon loss = 10757.6999, train kl loss = 30837.2846; total val loss = 29539.9871, val recon loss = 2333.4166 & val kl loss = 6205.8210
# epoch = 42; total train loss = 137798.1989, train recon loss = 10686.7949, train kl loss = 30930.2499; total val loss = 29518.5953, val recon loss = 2306.2944 & val kl loss = 6455.6514
# epoch = 43; total train loss = 137157.9355, train recon loss = 10616.9600, train kl loss = 30988.3356; total val loss = 29303.2433, val recon loss = 2310.9755 & val kl loss = 6193.4886
# epoch = 44; total train loss = 136558.7227, train recon loss = 10547.6709, train kl loss = 31082.0136; total val loss = 29404.8739, val recon loss = 2331.3975 & val kl loss = 6090.8986
# epoch = 45; total train loss = 136027.5395, train recon loss = 10482.6381, train kl loss = 31201.1587; total val loss = 29383.6753, val recon loss = 2310.5644 & val kl loss = 6278.0309
# epoch = 46; total train loss = 135468.0067, train recon loss = 10420.9146, train kl loss = 31258.8603; total val loss = 29846.3611, val recon loss = 2355.3660 & val kl loss = 6292.7016
# epoch = 47; total train loss = 134746.0808, train recon loss = 10339.7297, train kl loss = 31348.7837; total val loss = 29501.2798, val recon loss = 2309.7428 & val kl loss = 6403.8520
# epoch = 48; total train loss = 134326.9379, train recon loss = 10287.9689, train kl loss = 31447.2489; total val loss = 29591.2637, val recon loss = 2334.7779 & val kl loss = 6243.4842
# epoch = 49; total train loss = 133892.7368, train recon loss = 10238.5224, train kl loss = 31507.5126; total val loss = 29437.6496, val recon loss = 2317.4914 & val kl loss = 6262.7359
# epoch = 50; total train loss = 133198.0537, train recon loss = 10162.5115, train kl loss = 31572.9385; total val loss = 29441.4160, val recon loss = 2304.2252 & val kl loss = 6399.1640
# epoch = 51; total train loss = 132558.8147, train recon loss = 10092.7110, train kl loss = 31631.7043; total val loss = 29508.3336, val recon loss = 2307.3981 & val kl loss = 6434.3528
# epoch = 52; total train loss = 132023.4164, train recon loss = 10033.1279, train kl loss = 31692.1377; total val loss = 29613.1153, val recon loss = 2310.0068 & val kl loss = 6513.0471
# epoch = 53; total train loss = 131513.2649, train recon loss = 9973.0041, train kl loss = 31783.2238; total val loss = 29383.3778, val recon loss = 2303.0481 & val kl loss = 6352.8964
# epoch = 54; total train loss = 130963.9763, train recon loss = 9907.8599, train kl loss = 31885.3776; total val loss = 29499.1151, val recon loss = 2305.6654 & val kl loss = 6442.4617
# epoch = 55; total train loss = 130407.9067, train recon loss = 9845.7881, train kl loss = 31950.0252; total val loss = 29502.7218, val recon loss = 2315.7822 & val kl loss = 6344.8999
# epoch = 56; total train loss = 129876.4906, train recon loss = 9787.9240, train kl loss = 31997.2511; total val loss = 29464.6721, val recon loss = 2306.1253 & val kl loss = 6403.4195
# epoch = 57; total train loss = 129278.7272, train recon loss = 9716.2866, train kl loss = 32115.8610; total val loss = 29402.5120, val recon loss = 2294.6821 & val kl loss = 6455.6909
# epoch = 58; total train loss = 128871.8344, train recon loss = 9671.6903, train kl loss = 32154.9314; total val loss = 29537.3496, val recon loss = 2318.0856 & val kl loss = 6356.4938
# epoch = 59; total train loss = 128177.2071, train recon loss = 9592.6857, train kl loss = 32250.3501; total val loss = 29554.5973, val recon loss = 2309.0618 & val kl loss = 6463.9789
# epoch = 60; total train loss = 127763.7663, train recon loss = 9543.8599, train kl loss = 32325.1667; total val loss = 29639.2469, val recon loss = 2319.6896 & val kl loss = 6442.3515
# epoch = 61; total train loss = 127294.9880, train recon loss = 9491.3357, train kl loss = 32381.6309; total val loss = 29745.1006, val recon loss = 2322.9887 & val kl loss = 6515.2138
# epoch = 62; total train loss = 126702.8733, train recon loss = 9422.1522, train kl loss = 32481.3515; total val loss = 29954.4875, val recon loss = 2335.0733 & val kl loss = 6603.7546
# epoch = 63; total train loss = 126221.1945, train recon loss = 9361.6029, train kl loss = 32605.1658; total val loss = 29875.1445, val recon loss = 2331.5665 & val kl loss = 6559.4792
# epoch = 64; total train loss = 125786.2694, train recon loss = 9315.7730, train kl loss = 32628.5398; total val loss = 29695.3379, val recon loss = 2321.8125 & val kl loss = 6477.2126
# epoch = 65; total train loss = 125172.9882, train recon loss = 9247.8950, train kl loss = 32694.0379; total val loss = 29869.1422, val recon loss = 2331.5283 & val kl loss = 6553.8589
# epoch = 66; total train loss = 124772.6763, train recon loss = 9203.0466, train kl loss = 32742.2101; total val loss = 29771.2530, val recon loss = 2317.7295 & val kl loss = 6593.9578
# epoch = 67; total train loss = 124297.0794, train recon loss = 9147.3694, train kl loss = 32823.3849; total val loss = 29928.7289, val recon loss = 2335.3631 & val kl loss = 6575.0981
# epoch = 68; total train loss = 123776.7324, train recon loss = 9091.5341, train kl loss = 32861.3914; total val loss = 30084.0758, val recon loss = 2342.8063 & val kl loss = 6656.0122
# epoch = 69; total train loss = 123326.6029, train recon loss = 9032.9497, train kl loss = 32997.1053; total val loss = 30065.5805, val recon loss = 2349.6711 & val kl loss = 6568.8697
# epoch = 70; total train loss = 122911.5765, train recon loss = 8987.8776, train kl loss = 33032.8009; total val loss = 30030.9059, val recon loss = 2339.2799 & val kl loss = 6638.1073
# epoch = 71; total train loss = 122519.5148, train recon loss = 8944.3711, train kl loss = 33075.8032; total val loss = 30147.3133, val recon loss = 2342.6759 & val kl loss = 6720.5544
# epoch = 72; total train loss = 122079.9396, train recon loss = 8893.5893, train kl loss = 33144.0469; total val loss = 30024.2575, val recon loss = 2333.6219 & val kl loss = 6688.0385
# epoch = 73; total train loss = 121768.6439, train recon loss = 8857.9714, train kl loss = 33188.9301; total val loss = 30034.0613, val recon loss = 2335.6679 & val kl loss = 6677.3824
# epoch = 74; total train loss = 121338.7997, train recon loss = 8805.9192, train kl loss = 33279.6073; total val loss = 30386.2957, val recon loss = 2368.1661 & val kl loss = 6704.6346
# epoch = 75; total train loss = 120947.3412, train recon loss = 8766.4192, train kl loss = 33283.1496; total val loss = 30137.0461, val recon loss = 2355.9044 & val kl loss = 6578.0019
# epoch = 76; total train loss = 120561.8634, train recon loss = 8717.8250, train kl loss = 33383.6129; total val loss = 30194.3878, val recon loss = 2349.6504 & val kl loss = 6697.8839
# epoch = 77; total train loss = 120120.1584, train recon loss = 8670.2352, train kl loss = 33417.8063; total val loss = 30549.3388, val recon loss = 2377.0345 & val kl loss = 6778.9938
# epoch = 78; total train loss = 119770.6823, train recon loss = 8635.1079, train kl loss = 33419.6034; total val loss = 30452.4141, val recon loss = 2386.2044 & val kl loss = 6590.3705
# epoch = 79; total train loss = 119437.6873, train recon loss = 8592.3169, train kl loss = 33514.5180; total val loss = 30526.8408, val recon loss = 2388.2924 & val kl loss = 6643.9172
# epoch = 80; total train loss = 119086.9524, train recon loss = 8552.5154, train kl loss = 33561.7981; total val loss = 30318.2554, val recon loss = 2372.4510 & val kl loss = 6593.7456
# epoch = 81; total train loss = 118838.8887, train recon loss = 8521.3469, train kl loss = 33625.4191; total val loss = 30232.4931, val recon loss = 2353.4515 & val kl loss = 6697.9777
# epoch = 82; total train loss = 118531.5761, train recon loss = 8487.2617, train kl loss = 33658.9591; total val loss = 30405.2894, val recon loss = 2365.0309 & val kl loss = 6754.9803
# epoch = 83; total train loss = 118013.4111, train recon loss = 8432.9325, train kl loss = 33684.0864; total val loss = 30522.9755, val recon loss = 2381.7495 & val kl loss = 6705.4803
# epoch = 84; total train loss = 117787.8247, train recon loss = 8401.2403, train kl loss = 33775.4214; total val loss = 30495.6467, val recon loss = 2385.9901 & val kl loss = 6635.7456
# epoch = 85; total train loss = 117469.7865, train recon loss = 8367.4954, train kl loss = 33794.8323; total val loss = 30527.1574, val recon loss = 2376.3513 & val kl loss = 6763.6445
# epoch = 86; total train loss = 117170.3746, train recon loss = 8331.9336, train kl loss = 33851.0388; total val loss = 30731.9943, val recon loss = 2388.3695 & val kl loss = 6848.2993
# epoch = 87; total train loss = 116781.8135, train recon loss = 8288.6901, train kl loss = 33894.9123; total val loss = 30596.4106, val recon loss = 2379.6207 & val kl loss = 6800.2035
# epoch = 88; total train loss = 116563.4749, train recon loss = 8262.0480, train kl loss = 33942.9952; total val loss = 30605.9720, val recon loss = 2371.4691 & val kl loss = 6891.2813
# epoch = 89; total train loss = 116290.1459, train recon loss = 8228.5254, train kl loss = 34004.8918; total val loss = 30930.0671, val recon loss = 2401.7283 & val kl loss = 6912.7840
# epoch = 90; total train loss = 116029.0209, train recon loss = 8200.8088, train kl loss = 34020.9326; total val loss = 30619.5460, val recon loss = 2394.9170 & val kl loss = 6670.3761
# epoch = 91; total train loss = 115670.1038, train recon loss = 8161.2897, train kl loss = 34057.2071; total val loss = 30714.6623, val recon loss = 2399.5869 & val kl loss = 6718.7933
# epoch = 92; total train loss = 115418.1596, train recon loss = 8129.9926, train kl loss = 34118.2333; total val loss = 30682.9829, val recon loss = 2400.7963 & val kl loss = 6675.0198
# epoch = 93; total train loss = 115160.9793, train recon loss = 8100.4938, train kl loss = 34156.0411; total val loss = 30834.3181, val recon loss = 2383.6925 & val kl loss = 6997.3929
# epoch = 94; total train loss = 114825.2231, train recon loss = 8067.6816, train kl loss = 34148.4073; total val loss = 30795.1731, val recon loss = 2383.2787 & val kl loss = 6962.3864
# epoch = 95; total train loss = 114577.2303, train recon loss = 8038.4494, train kl loss = 34192.7359; total val loss = 30922.5387, val recon loss = 2393.0836 & val kl loss = 6991.7027
# epoch = 96; total train loss = 114333.1357, train recon loss = 8010.3372, train kl loss = 34229.7636; total val loss = 31070.7280, val recon loss = 2406.0099 & val kl loss = 7010.6294
# epoch = 97; total train loss = 114165.6118, train recon loss = 7985.8062, train kl loss = 34307.5499; total val loss = 31109.1771, val recon loss = 2416.2279 & val kl loss = 6946.8977
# epoch = 98; total train loss = 113884.1864, train recon loss = 7956.4842, train kl loss = 34319.3449; total val loss = 31134.9300, val recon loss = 2417.9358 & val kl loss = 6955.5725
# epoch = 99; total train loss = 113602.7021, train recon loss = 7922.7178, train kl loss = 34375.5247; total val loss = 31102.2828, val recon loss = 2422.0441 & val kl loss = 6881.8421
# epoch = 100; total train loss = 113364.1217, train recon loss = 7900.6344, train kl loss = 34357.7775; total val loss = 31129.2475, val recon loss = 2415.2025 & val kl loss = 6977.2228

# %%
train_dataset
# Out:
# <BatchDataset element_spec=TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name=None)>

# %%
for idx, data in enumerate(train_dataset):
    if idx==0:
        x_data = data
    else:
        break

# %%
x_data = X_train[:1000]
y_data = y_train[:1000]

# %%
data_recon, mu, log_var = model(x_data)

# %%
model.decoder.model().summary()#().summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 100)]             0
#
#  dense_13 (Dense)            (None, 100)               10100
#
#  batch_normalization_39 (Bat  (None, 100)              400
#  chNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 100)               0
#
#  dense_14 (Dense)            (None, 1024)              103424
#
#  batch_normalization_40 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 1024)              0
#
#  dense_15 (Dense)            (None, 4096)              4198400
#
#  batch_normalization_41 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 4096)              0
#
#  reshape_2 (Reshape)         (None, 4, 4, 256)         0
#
#  conv2d_transpose_14 (Conv2D  (None, 8, 8, 256)        590080
#  Transpose)
#
#  batch_normalization_42 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_15 (Conv2D  (None, 8, 8, 256)        590080
#  Transpose)
#
#  batch_normalization_43 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_16 (Conv2D  (None, 16, 16, 128)      295040
#  Transpose)
#
#  batch_normalization_44 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_17 (Conv2D  (None, 16, 16, 128)      147584
#  Transpose)
#
#  batch_normalization_45 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_18 (Conv2D  (None, 32, 32, 64)       73792
#  Transpose)
#
#  batch_normalization_46 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_19 (Conv2D  (None, 32, 32, 64)       36928
#  Transpose)
#
#  batch_normalization_47 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 6,071,623
# Trainable params: 6,059,391
# Non-trainable params: 12,232
# _________________________________________________________________

# %%
plt.imshow(data_recon[i])

# %%
x_data = tf.data.Dataset.from_tensor_slices(X_train).batch(batch_size = batch_size)

# %%
z_list = list()
for idx, batch in enumerate(x_data):
    recon, mu, logvar, z = model(batch)
    z_list.append(z)

# %%
len(z_list)
# Out:
# 782

# %%
z_list[0].shape
# Out:
# TensorShape([64, 100])

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)
